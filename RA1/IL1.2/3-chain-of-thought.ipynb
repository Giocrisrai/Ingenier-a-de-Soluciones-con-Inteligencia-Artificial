# %% [markdown]
# # 3. Chain-of-Thought (CoT) Prompting - Razonamiento Paso a Paso
#
# ## Objetivos de Aprendizaje
# - Comprender el concepto de Chain-of-Thought (CoT) prompting
# - Implementar CoT con y sin ejemplos
# - Aplicar CoT a problemas complejos y razonamiento lógico
# - Combinar CoT con otras técnicas de prompting
#
# ## ¿Qué es Chain-of-Thought?
#
# Chain-of-Thought (CoT) es una técnica que hace que el modelo "**piense en voz alta**" mostrando su proceso de razonamiento paso a paso antes de llegar a la respuesta final.
#
# ### Principio Básico:
# En lugar de saltar directamente a la respuesta, el modelo:
# 1. **Descompone** el problema en pasos
# 2. **Razona** cada paso explícitamente
# 3. **Construye** hacia la solución final
# 4. **Proporciona** la respuesta con justificación
#
# ### Ventajas:
# - **Mejor precisión**: Especialmente en problemas complejos
# - **Transparencia**: Puedes ver el razonamiento
# - **Debugging**: Identificar dónde falla el razonamiento
# - **Confianza**: Mayor seguridad en la respuesta
#
# ### Casos de Uso Ideales:
# - Problemas matemáticos
# - Razonamiento lógico
# - Análisis complejos
# - Toma de decisiones
# - Resolución de problemas multi-paso

# %%
# Configuración inicial
import os

# Carga de credenciales: funciona igual en Google Colab y en local (.env)
try:
    from google.colab import userdata  # type: ignore
    os.environ["GROQ_API_KEY"] = userdata.get("GROQ_API_KEY")
except ImportError:
    from dotenv import load_dotenv
    load_dotenv()

assert os.getenv("GROQ_API_KEY"), "Falta GROQ_API_KEY (Colab: Secrets · local: archivo .env)"

MODELO = os.getenv("GROQ_MODEL", "openai/gpt-oss-120b")

from langchain_groq import ChatGroq
from langchain_core.messages import HumanMessage
import time

# Configurar el modelo (ChatGroq lee GROQ_API_KEY del entorno automáticamente)
llm = ChatGroq(
    model=MODELO,
    temperature=0.1,  # Baja temperatura para razonamiento más consistente,
    reasoning_effort="low"
    )

print("✓ Modelo configurado para Chain-of-Thought")
print("✓ Temperature baja para razonamiento consistente")
# Out:
# ✓ Modelo configurado para Chain-of-Thought
# ✓ Temperature baja para razonamiento consistente

# %% [markdown]
# ## Comparación: Sin CoT vs Con CoT
#
# Veamos la diferencia dramática que puede hacer CoT en problemas complejos.

# %%
# Comparación directa: razonamiento directo vs CoT
def comparar_sin_vs_con_cot():
    print("=== COMPARACIÓN: SIN CoT vs CON CoT ===")
    
    # Problema complejo que requiere múltiples pasos
    problema = """Una tienda tiene una promoción: 'Compra 2 productos y obtén 30% de descuento en el más barato'. 
    Juan compra una camiseta de 45€, unos zapatos de 120€ y una chaqueta de 80€. 
    ¿Cuánto paga en total?"""
    
    # Prompt sin CoT
    prompt_sin_cot = f"""Resuelve este problema:
    
{problema}
    
Respuesta:"""
    
    # Prompt con CoT
    prompt_con_cot = f"""Resuelve este problema paso a paso:
    
{problema}
    
Piensa paso a paso:
1. Primero identifica los productos y precios
2. Determina cómo se aplica la promoción
3. Calcula el descuento
4. Calcula el total final
    
Razonamiento:"""
    
    # Probar sin CoT
    print("\n1. SIN CHAIN-OF-THOUGHT:")
    print("-" * 30)
    try:
        response_sin = llm.invoke([HumanMessage(content=prompt_sin_cot)])
        print(response_sin.content)
    except Exception as e:
        print(f"Error: {e}")
    
    print("\n" + "="*60)
    
    # Probar con CoT
    print("\n2. CON CHAIN-OF-THOUGHT:")
    print("-" * 30)
    try:
        response_con = llm.invoke([HumanMessage(content=prompt_con_cot)])
        print(response_con.content)
    except Exception as e:
        print(f"Error: {e}")
    
    print("\n=== ANÁLISIS ===")
    print("• Sin CoT: Puede llegar a respuesta incorrecta o saltar pasos")
    print("• Con CoT: Muestra razonamiento completo y reduce errores")
    print("• CoT especialmente útil para problemas multi-paso")

# Ejecutar comparación
comparar_sin_vs_con_cot()
# Out:
# === COMPARACIÓN: SIN CoT vs CON CoT ===
#
# 1. SIN CHAIN-OF-THOUGHT:
# ------------------------------
# Los precios de los productos son:
#
# - Camiseta: 45 €
# - Zapatos: 120 €
# - Chaqueta: 80 €
#
# **1. Sumar los precios sin descuento**
#
# \[
# 45 + 120 + 80 = 245 \text{ €}
# \]
#
# **2. Identificar el producto más barato**
# El más barato es la camiseta (45 €).
#
# **3. Calcular el descuento del 30 % sobre ese producto**
#
# \[
# 30\% \times 45 = 0{,}30 \times 45 = 13{,}5 \text{ €}
# \]
#
# **4. Restar el descuento al total**
#
# \[
# 245 - 13{,}5 = 231{,}5 \text{ €}
# \]
#
# ---
#
# **Respuesta:** Juan paga **231,5 €** en total.
#
# ============================================================
#
# 2. CON CHAIN-OF-THOUGHT:
# ------------------------------
# **Paso 1 – Identificar los productos y sus precios**
#
# | Producto   | Precio (€) |
# |------------|------------|
# | Camiseta   | 45 € |
# | Zapatos    | 120 € |
# | Chaqueta   | 80 € |
#
# **Paso 2 – Determinar cómo se aplica la promoción**
#
# La promoción dice: *“Compra 2 productos y obtén 30 % de descuento en el más barato”*.
# - Cada vez que se compran **dos** artículos, el más barato de esos dos recibe un 30 % de descuento.
# - Juan lleva **tres** productos, por lo que solo puede formar **un** par de dos productos (el tercer artículo queda fuera de la promoción).
# - Para maximizar el ahorro, elegimos el par que deje el mayor descuento posible: el par debe contener al artículo **más caro** (zapatos 120 €) y al **más barato** del resto (camiseta 45 €). Así el artículo más barato del par (la camiseta) recibe el 30 % de descuento.
#
# **Paso 3 – Calcular el descuento**
#
# - Precio de la camiseta (más barata del par): 45 €
# - Descuento del 30 %:
#
# \[
# \text{Descuento} = 45 € \times 0.30 = 13.5 €
# \]
#
# - Precio de la camiseta con descuento:
#
# \[
# 45 € - 13.5 € = 31.5 €
# \]
#
# **Paso 4 – Calcular el total final**
#
# Sumamos los precios después de aplicar el descuento:
#
# - Camiseta (con descuento): 31.5 €
# - Zapatos (sin descuento): 120 €
# - Chaqueta (sin descuento): 80 €
#
# \[
# \text{Total} = 31.5 € + 120 € + 80 € = 231.5 €
# \]
#
# ---
#
# ## Resultado
#
# Juan paga **231,50 €** en total después de aplicar la promoción.
#
# === ANÁLISIS ===
# • Sin CoT: Puede llegar a respuesta incorrecta o saltar pasos
# • Con CoT: Muestra razonamiento completo y reduce errores
# • CoT especialmente útil para problemas multi-paso

# %% [markdown]
# ## Zero-Shot Chain-of-Thought
#
# La forma más simple de CoT: simplemente pedirle al modelo que "piense paso a paso".

# %%
# Zero-shot CoT: solo agregar "piensa paso a paso"
def zero_shot_cot():
    print("=== ZERO-SHOT CHAIN-OF-THOUGHT ===")
    
    problemas = [
        "Si un tren viaja a 80 km/h y necesita llegar a una ciudad que está a 240 km, pero se detiene 15 minutos en una estación intermedia, ¿cuánto tiempo total toma el viaje?",
        "Una empresa tiene 150 empleados. El 40% trabaja en desarrollo, el 25% en ventas, el 20% en marketing y el resto en administración. Si cada empleado de desarrollo gana 50,000€ anuales, ¿cuál es el costo anual solo del departamento de desarrollo?",
        "María tiene el triple de edad que su hermana Ana. En 5 años, María tendrá el doble de la edad que tendrá Ana. ¿Cuántos años tiene cada una ahora?"
    ]
    
    for i, problema in enumerate(problemas, 1):
        print(f"\n{i}. PROBLEMA:")
        print(f"{problema}")
        
        # Prompt zero-shot CoT
        prompt = f"{problema}\n\nPiensa paso a paso:"
        
        try:
            response = llm.invoke([HumanMessage(content=prompt)])
            print("\nSOLUCIÓN:")
            print(response.content)
            
            # Análisis básico del razonamiento
            pasos = response.content.count('\n')
            tiene_calculo = any(op in response.content for op in ['+', '-', '*', '/', '=', '%'])
            
            print(f"\nAnálisis: {pasos} líneas de razonamiento, {'con' if tiene_calculo else 'sin'} cálculos explícitos")
            
        except Exception as e:
            print(f"Error: {e}")
        
        print("-" * 80)

# Ejecutar zero-shot CoT
zero_shot_cot()
# Out:
# === ZERO-SHOT CHAIN-OF-THOUGHT ===
#
# 1. PROBLEMA:
# Si un tren viaja a 80 km/h y necesita llegar a una ciudad que está a 240 km, pero se detiene 15 minutos en una estación intermedia, ¿cuánto tiempo total toma el viaje?
#
# SOLUCIÓN:
# **Paso a paso**
#
# 1. **Calcular el tiempo de marcha**
#    - Velocidad del tren: \(80 \text{ km/h}\)
#    - Distancia total: \(240 \text{ km}\)
#
#    \[
#    \text{Tiempo de marcha} = \frac{\text{Distancia}}{\text{Velocidad}} = \frac{240 \text{ km}}{80 \text{ km/h}} = 3 \text{ h}
#    \]
#
# 2. **Añadir la parada en la estación intermedia**
#    - Duración de la parada: 15 minutos = \(\frac{15}{60} = 0.25 \text{ h}\)
#
# 3. **Tiempo total del viaje**
#
#    \[
#    \text{Tiempo total} = 3 \text{ h} + 0.25 \text{ h} = 3.25 \text{ h}
#    \]
#
#    Convertido a horas y minutos:
#
#    \[
#    3.25 \text{ h} = 3 \text{ h} + 0.25 \times 60 \text{ min} = 3 \text{ h} 15 \text{ min}
#    \]
#
# ---
#
# **Respuesta:** El viaje completo, incluyendo la parada de 15 minutos, tarda **3 horas y 15 minutos**.
#
# Análisis: 27 líneas de razonamiento, con cálculos explícitos
# --------------------------------------------------------------------------------
#
# 2. PROBLEMA:
# Una empresa tiene 150 empleados. El 40% trabaja en desarrollo, el 25% en ventas, el 20% en marketing y el resto en administración. Si cada empleado de desarrollo gana 50,000€ anuales, ¿cuál es el costo anual solo del departamento de desarrollo?
#
# SOLUCIÓN:
# **Paso a paso**
#
# 1. **Calcular cuántos empleados están en desarrollo**
#    - El 40 % de los 150 empleados trabaja en desarrollo.
#    - \(0,40 \times 150 = 60\) empleados.
#
# 2. **Calcular el costo total del departamento de desarrollo**
#    - Cada uno de esos 60 empleados gana 50 000 € al año.
#    - Costo total = \(60 \times 50\,000\ € = 3\,000\,000\ €\).
#
# **Respuesta:** El costo anual del departamento de desarrollo es **3 000 000 €**.
#
# Análisis: 10 líneas de razonamiento, con cálculos explícitos
# --------------------------------------------------------------------------------
#
# 3. PROBLEMA:
# María tiene el triple de edad que su hermana Ana. En 5 años, María tendrá el doble de la edad que tendrá Ana. ¿Cuántos años tiene cada una ahora?
#
# SOLUCIÓN:
# **Paso 1: Definir las incógnitas**
# - Sea \(A\) la edad actual de Ana.
# - Sea \(M\) la edad actual de María.
#
# **Paso 2: Plantear las relaciones dadas**
#
# 1. “María tiene el triple de edad que su hermana Ana”
#    \[
#    M = 3A
#    \]
#
# 2. “En 5 años, María tendrá el doble de la edad que tendrá Ana”
#    \[
#    M + 5 = 2\,(A + 5)
#    \]
#
# **Paso 3: Sustituir la primera ecuación en la segunda**
#
# Reemplazamos \(M\) por \(3A\) en la segunda ecuación:
#
# \[
# 3A + 5 = 2(A + 5)
# \]
#
# **Paso 4: Resolver la ecuación**
#
# \[
# \begin{aligned}
# 3A + 5 &= 2A + 10 \\
# 3A - 2A &= 10 - 5 \\
# A &= 5
# \end{aligned}
# \]
#
# **Paso 5: Encontrar la edad de María**
#
# Usamos \(M = 3A\):
#
# \[
# M = 3 \times 5 = 15
# \]
#
# **Resultado**
#
# - Ana tiene **5 años**.
# - María tiene **15 años**.
#
# Comprobación rápida:
# - En 5 años, Ana tendrá \(5 + 5 = 10\) años.
# - En 5 años, María tendrá \(15 + 5 = 20\) años, que es exactamente el doble de 10. ✅
#
# Análisis: 49 líneas de razonamiento, con cálculos explícitos
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Few-Shot Chain-of-Thought
#
# Combinamos CoT con ejemplos para mostrar el patrón de razonamiento deseado.

# %%
# Few-shot CoT: ejemplos con razonamiento paso a paso
def few_shot_cot():
    print("=== FEW-SHOT CHAIN-OF-THOUGHT ===")
    
    # Nuevo problema para resolver
    nuevo_problema = "Un parking cobra 3€ la primera hora y 2€ cada hora adicional. Si alguien paga 15€, ¿cuántas horas estuvo estacionado?"
    
    # Prompt con ejemplos de razonamiento
    prompt_few_shot_cot = f"""Resuelve problemas matemáticos mostrando el razonamiento paso a paso:
    
Problema: Una pizza cuesta 12€ y cada ingrediente extra cuesta 1.50€. Si Pedro paga 18€, ¿cuántos ingredientes extra pidió?
Razonamiento:
1. Precio base de la pizza: 12€
2. Total pagado: 18€
3. Dinero gastado en extras: 18€ - 12€ = 6€
4. Costo por ingrediente extra: 1.50€
5. Número de ingredientes: 6€ ÷ 1.50€ = 4 ingredientes
Respuesta: Pedro pidió 4 ingredientes extra.
    
Problema: En una clase hay 24 estudiantes. Si se forman grupos de 6 estudiantes cada uno, ¿cuántos grupos se pueden formar? Si sobra algún estudiante, ¿cuántos?
Razonamiento:
1. Total de estudiantes: 24
2. Estudiantes por grupo: 6
3. División: 24 ÷ 6 = 4 grupos exactos
4. Verificación: 4 × 6 = 24 estudiantes
5. Resto: 24 - 24 = 0 estudiantes sobran
Respuesta: Se pueden formar 4 grupos completos y no sobra ningún estudiante.
    
Problema: {nuevo_problema}
Razonamiento:"""
    
    try:
        response = llm.invoke([HumanMessage(content=prompt_few_shot_cot)])
        print("PROBLEMA A RESOLVER:")
        print(nuevo_problema)
        print("\nSOLUCIÓN CON RAZONAMIENTO:")
        print(response.content)
        
        # Verificar si siguió el patrón
        razonamiento = response.content
        tiene_pasos_numerados = bool(re.search(r'\d+\.', razonamiento))
        tiene_calculos = any(op in razonamiento for op in ['=', '+', '-', '*', '/', '€'])
        tiene_respuesta_final = 'respuesta' in razonamiento.lower()
        
        print("\n=== ANÁLISIS DEL PATRÓN ===")
        print(f"✓ Pasos numerados: {'Sí' if tiene_pasos_numerados else 'No'}")
        print(f"✓ Cálculos explícitos: {'Sí' if tiene_calculos else 'No'}")
        print(f"✓ Respuesta final clara: {'Sí' if tiene_respuesta_final else 'No'}")
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar few-shot CoT
import re
few_shot_cot()
# Out:
# === FEW-SHOT CHAIN-OF-THOUGHT ===
# PROBLEMA A RESOLVER:
# Un parking cobra 3€ la primera hora y 2€ cada hora adicional. Si alguien paga 15€, ¿cuántas horas estuvo estacionado?
#
# SOLUCIÓN CON RAZONAMIENTO:
# **Problema:** Un parking cobra 3 € la primera hora y 2 € cada hora adicional. Si alguien paga 15 €, ¿cuántas horas estuvo estacionado?
#
# **Razonamiento paso a paso**
#
# 1. **Identificar los datos del problema**
#    - Precio de la **primera hora** = 3 €.
#    - Precio de **cada hora adicional** = 2 €.
#    - **Total pagado** = 15 €.
#
# 2. **Separar el costo de la primera hora del total**
#    Como la primera hora tiene un precio distinto, la restamos del total para saber cuánto se gastó en las horas adicionales.
#
#    \[
#    \text{Dinero gastado en horas adicionales} = 15 € - 3 € = 12 €
#    \]
#
# 3. **Calcular cuántas horas adicionales corresponden a esos 12 €**
#    Cada hora adicional cuesta 2 €, por lo que dividimos el dinero disponible para horas adicionales entre el costo por hora:
#
#    \[
#    \text{Número de horas adicionales} = \frac{12 €}{2 €/h} = 6 \text{ horas}
#    \]
#
# 4. **Sumar la primera hora**
#    El total de horas estacionado es la primera hora más las horas adicionales:
#
#    \[
#    \text{Horas totales} = 1 \text{ (primera hora)} + 6 \text{ (adicionales)} = 7 \text{ horas}
#    \]
#
# 5. **Verificación**
#    - Costo de la primera hora: 1 × 3 € = 3 €.
#    - Costo de las 6 horas adicionales: 6 × 2 € = 12 €.
#    - Suma total: 3 € + 12 € = 15 €, que coincide con lo pagado.
#
# **Respuesta:** La persona estuvo estacionada **7 horas**.
#
# === ANÁLISIS DEL PATRÓN ===
# ✓ Pasos numerados: Sí
# ✓ Cálculos explícitos: Sí
# ✓ Respuesta final clara: Sí

# %% [markdown]
# ## CoT para Razonamiento Lógico
#
# Chain-of-Thought es especialmente poderoso para problemas de lógica y deducción.

# %%
# CoT para problemas de lógica
def cot_razonamiento_logico():
    print("=== CoT PARA RAZONAMIENTO LÓGICO ===")
    
    # Problema de lógica clásico
    problema_logica = """En una mesa redonda se sientan 5 personas: Ana, Bruno, Carlos, Diana y Elena.
    - Ana no está al lado de Bruno
    - Carlos está exactamente frente a Diana
    - Elena está al lado derecho de Ana
    - Bruno está al lado de Carlos
    
¿Cuál es la disposición completa alrededor de la mesa?"""
    
    prompt_logica = f"""Resuelve este problema de lógica paso a paso:
    
{problema_logica}
    
Razona sistemáticamente:
1. Identifica las restricciones
2. Establece relaciones conocidas
3. Deduce posiciones paso a paso
4. Verifica que se cumplan todas las condiciones
    
Proceso de deducción:"""
    
    try:
        response = llm.invoke([HumanMessage(content=prompt_logica)])
        print("PROBLEMA DE LÓGICA:")
        print(problema_logica)
        print("\nPROCESO DE RAZONAMIENTO:")
        print(response.content)
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar razonamiento lógico
cot_razonamiento_logico()
# Out:
# === CoT PARA RAZONAMIENTO LÓGICO ===
# PROBLEMA DE LÓGICA:
# En una mesa redonda se sientan 5 personas: Ana, Bruno, Carlos, Diana y Elena.
#     - Ana no está al lado de Bruno
#     - Carlos está exactamente frente a Diana
#     - Elena está al lado derecho de Ana
#     - Bruno está al lado de Carlos
#
# ¿Cuál es la disposición completa alrededor de la mesa?
#
# PROCESO DE RAZONAMIENTO:
# **Problema**
# En una mesa redonda hay 5 personas: **Ana (A), Bruno (B), Carlos (C), Diana (D) y Elena (E)**.
# Se deben colocar de modo que se cumplan las siguientes condiciones:
#
# 1. **A no está al lado de B**.
# 2. **C está exactamente frente a D**.
# 3. **E está al lado derecho de A**.
# 4. **B está al lado de C**.
#
# Con 5 personas la mesa tiene 5 asientos. Cuando decimos “frente” en una mesa de número impar, el asiento “frente” es el que queda a **dos posiciones de distancia** (es decir, el asiento opuesto en un pentágono regular).
#
# ---
#
# ## 1. Identificación de las restricciones
#
# | Restricción | Qué implica |
# |-------------|-------------|
# | (R1) A ↛ B | A y B no pueden ser vecinos. |
# | (R2) C ↔ D | C y D deben estar separados por dos asientos (C‑X‑D). |
# | (R3) E = derecha de A | Si miramos al centro, el asiento inmediatamente a la **derecha** de A debe ser E. |
# | (R4) B ↔ C | B y C deben ser vecinos (en cualquier orden). |
#
# ---
#
# ## 2. Relaciones conocidas (primeras deducciones)
#
# 1. **R3 fija una pareja ordenada**:
#    - Si numeramos los asientos en sentido horario (sentido de las agujas del reloj) como 1‑2‑3‑4‑5, “lado derecho de A” significa que **E ocupa el asiento inmediatamente siguiente en sentido horario**.
#    - Por tanto, la pareja **A‑E** siempre aparece como **A → E** (A en una posición, E en la siguiente en sentido horario).
#
# 2. **R4 obliga a que B y C sean vecinos**.
#    - Como A‑E ya ocupa dos asientos consecutivos, los pares posibles para (B,C) deben situarse en los tres asientos restantes, siempre contiguos.
#
# 3. **R2 (C frente a D)**: con 5 asientos, “frente” equivale a “dos asientos de distancia”.
#    - Si C está en el asiento *i*, D debe estar en *i + 2* (mod 5).
#    - Esto determina automáticamente la posición de D una vez que se coloca C.
#
# ---
#
# ## 3. Deducción paso a paso
#
# ### Paso 0 – Elegir una referencia
# En problemas circulares podemos fijar arbitrariamente una persona en un asiento para eliminar la simetría de rotación.
# **Fijemos a Ana (A) en el asiento 1**.
#
# ```
# Asiento: 1   2   3   4   5
#           A
# ```
#
# ### Paso 1 – Colocar a Elena (E) a la derecha de A (R3)
# El “lado derecho” de A es el asiento 2 (sentido horario).
#
# ```
# Asiento: 1   2   3   4   5
#           A   E
# ```
#
# ### Paso 2 – Determinar los asientos disponibles
# Quedan libres los asientos **3, 4 y 5** para B, C y D.
#
# ### Paso 3 – Aplicar la condición B ↔ C (R4)
# B y C deben ser vecinos. Con tres asientos libres, hay **dos formas** de colocar una pareja contigua:
#
# - **Opción A**: B en 3, C en 4 (o viceversa).
# - **Opción B**: B en 4, C en 5 (o viceversa).
#
# (La pareja no puede ocupar 3‑5 porque no son contiguos.)
#
# ### Paso 4 – Aplicar la condición C ↔ D (R2)
# Recordemos: D debe estar a dos asientos de C (C + 2 mod 5).
# Probemos cada opción.
#
# #### Opción A: (B‑C) en (3‑4)
#
# 1. **Caso A1**: B = 3, C = 4
#    - Entonces D debe estar en 4 + 2 = 6 ≡ 1 (mod 5).
#    - El asiento 1 ya está ocupado por A → **imposible**.
#
# 2. **Caso A2**: C = 3, B = 4
#    - D debe estar en 3 + 2 = 5.
#    - El asiento 5 está libre → **válido**.
#
#    Distribución provisional:
#
#    ```
#    1   2   3   4   5
#    A   E   C   B   D
#    ```
#
#    Verifiquemos R1 (A no al lado de B): A está en 1, B en 4 → no son vecinos (los vecinos de 1 son 5 y 2).
#    Todas las condiciones se cumplen.
#
# #### Opción B: (B‑C) en (4‑5)
#
# 1. **Caso B1**: B = 4, C = 5
#    - D debe estar en 5 + 2 = 7 ≡ 2.
#    - El asiento 2 está ocupado por E → **imposible**.
#
# 2. **Caso B2**: C = 4, B = 5
#    - D debe estar en 4 + 2 = 6 ≡ 1.
#    - El asiento 1 está ocupado por A → **imposible**.
#
# Por lo tanto, **solo la configuración A2 es viable**.
#
# ### Paso 5 – Verificación final de todas las restricciones
#
# | Persona | Asiento | Vecinos (horario) |
# |---------|---------|-------------------|
# | A       | 1       | (5 = D, 2 = E) |
# | E       | 2       | (1 = A, 3 = C) |
# | C       | 3       | (2 = E, 4 = B) |
# | B       | 4       | (3 = C, 5 = D) |
# | D       | 5       | (4 = B, 1 = A) |
#
# - **R1**: A (1) no está al lado de B (4) → ✔️
# - **R2**: C (3) y D (5) están separados por dos asientos (3 → 4 → 5) → ✔️
# - **R3**: E (2) está a la derecha de A (1) → ✔️
# - **R4**: B (4) y C (3) son vecinos → ✔️
#
# Todas las condiciones se cumplen.
#
# ---
#
# ## 4. Disposición completa alrededor de la mesa
#
# Si leemos la mesa en sentido horario (sentido de las agujas del reloj) a partir de Ana, obtenemos:
#
# **Ana → Elena → Carlos → Bruno → Diana**
#
# En notación circular:
#
# ```
# 1:A  → 2:E  → 3:C  → 4:B  → 5:D  → (vuelve a 1)
# ```
#
# Cualquier rotación de esta secuencia es equivalente (pues la mesa es redonda), pero la relación **“Elena a la derecha de Ana”** fija la orientación, de modo que la única disposición que satisface todas las condiciones es la mostrada arriba.

# %%
# CoT para análisis de casos complejos
def cot_analisis_complejo():
    print("=== CoT PARA ANÁLISIS COMPLEJO ===")
    
    # Caso de negocio complejo
    caso_negocio = """Una startup de software tiene las siguientes métricas:
    - 10,000 usuarios activos mensuales
    - Tasa de conversión a premium: 5%
    - Precio premium: 29€/mes
    - Costo de adquisición por usuario: 15€
    - Retención mensual: 85%
    - Costos operativos mensuales: 12,000€
    
La empresa está considerando reducir el precio a 19€/mes para aumentar la conversión a 8%. 
¿Es una buena decisión financiera?"""
    
    prompt_analisis = f"""Analiza este caso de negocio paso a paso:
    
{caso_negocio}
    
Estructura tu análisis:
1. Calcula métricas del escenario actual
2. Calcula métricas del escenario propuesto
3. Compara ingresos y costos
4. Considera factores adicionales
5. Proporciona recomendación fundamentada
    
Análisis detallado:"""
    
    try:
        response = llm.invoke([HumanMessage(content=prompt_analisis)])
        print("CASO DE NEGOCIO:")
        print(caso_negocio)
        print("\nANÁLISIS PASO A PASO:")
        print(response.content)
        
        # Verificar completitud del análisis
        analisis = response.content.lower()
        elementos_clave = [
            'ingresos', 'costos', 'beneficio', 'actual', 'propuesto', 
            'recomendación', 'conversión', 'usuarios'
        ]
        elementos_presentes = sum(1 for elemento in elementos_clave if elemento in analisis)
        
        print(f"\n=== COMPLETITUD DEL ANÁLISIS ===")
        print(f"✓ Elementos clave cubiertos: {elementos_presentes}/{len(elementos_clave)}")
        print(f"✓ Análisis completo: {'Sí' if elementos_presentes >= 6 else 'Parcial'}")
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar análisis complejo
cot_analisis_complejo()
# Out:
# === CoT PARA ANÁLISIS COMPLEJO ===
# CASO DE NEGOCIO:
# Una startup de software tiene las siguientes métricas:
#     - 10,000 usuarios activos mensuales
#     - Tasa de conversión a premium: 5%
#     - Precio premium: 29€/mes
#     - Costo de adquisición por usuario: 15€
#     - Retención mensual: 85%
#     - Costos operativos mensuales: 12,000€
#
# La empresa está considerando reducir el precio a 19€/mes para aumentar la conversión a 8%.
# ¿Es una buena decisión financiera?
#
# ANÁLISIS PASO A PASO:
# ## 1. Métricas del escenario actual
#
# | Concepto | Cálculo | Resultado |
# |----------|---------|-----------|
# | **Usuarios activos (UA)** | – | 10 000 |
# | **Conversión a premium** | 5 % de 10 000 | 500 usuarios premium |
# | **Precio premium** | 29 €/mes | – |
# | **Ingresos mensuales (MRR)** | 500 × 29 € | **14 500 €** |
# | **Costo de adquisición (CAC) total** | 10 000 × 15 € | **150 000 €** (costo de adquisición histórico; se amortiza a lo largo del tiempo) |
# | **Retención mensual** | 85 % → churn = 15 % | Cada mes se pierden 15 % de los premium |
# | **Churn mensual de premium** | 500 × 15 % = 75 usuarios | – |
# | **Costos operativos mensuales** | – | **12 000 €** |
# | **Beneficio operativo mensual** | 14 500 € – 12 000 € | **2 500 €** |
# | **Beneficio neto mensual (sin amortizar CAC)** | 2 500 € – (CAC/vida útil) | Depende de la vida útil estimada del cliente. Si asumimos 12 meses de vida útil, CAC mensual = 150 000 €/12 = 12 500 €, lo que daría **‑10 000 €** de flujo neto. |
#
# > **Nota:** El CAC se paga una sola vez al adquirir al usuario, pero para valorar la rentabilidad se suele prorratear su coste a lo largo de la vida esperada del cliente (LTV). Usaremos esa lógica en la comparación.
#
# ### Cálculo del LTV (valor de vida del cliente) – escenario actual
# - **Ingresos promedio por cliente premium al mes (ARPU premium)** = 29 €
# - **Duración esperada** = 1 / churn mensual = 1 / 0.15 ≈ **6,67 meses**
# - **LTV** = 29 € × 6,67 ≈ **193 €**
#
# Como el CAC es 15 €, el **ratio LTV/CAC ≈ 12,9**, lo que indica una buena rentabilidad a nivel de cliente premium.
#
# ---
#
# ## 2. Métricas del escenario propuesto (precio 19 €/mes, conversión 8 %)
#
# | Concepto | Cálculo | Resultado |
# |----------|---------|-----------|
# | **Usuarios activos (UA)** | – | 10 000 |
# | **Conversión a premium** | 8 % de 10 000 | 800 usuarios premium |
# | **Precio premium** | 19 €/mes | – |
# | **Ingresos mensuales (MRR)** | 800 × 19 € | **15 200 €** |
# | **Retención mensual** | Se mantiene 85 % (asumimos que el cambio de precio no afecta la retención) | – |
# | **Churn mensual de premium** | 800 × 15 % = 120 usuarios | – |
# | **Costos operativos mensuales** | – | **12 000 €** |
# | **Beneficio operativo mensual** | 15 200 € – 12 000 € | **3 200 €** |
# | **CAC total** | 10 000 × 15 € = 150 000 € (igual que antes) | – |
# | **LTV (nuevo)** | ARPU = 19 €, churn = 15 % → duración = 6,67 meses → LTV = 19 € × 6,67 ≈ **127 €** |
# | **Ratio LTV/CAC** | 127 €/15 € ≈ **8,5** | – |
#
# ---
#
# ## 3. Comparación de ingresos y costos
#
# | Ítem | Escenario actual | Escenario propuesto |
# |------|------------------|----------------------|
# | **Premiums** | 500 | 800 |
# | **Precio** | 29 € | 19 € |
# | **MRR** | 14 500 € | 15 200 € |
# | **Incremento MRR** | — | **+700 €** (+4,8 %) |
# | **Beneficio operativo** | 2 500 € | 3 200 € |
# | **Incremento beneficio operativo** | — | **+700 €** (+28 %) |
# | **LTV** | 193 € | 127 € |
# | **Ratio LTV/CAC** | 12,9 | 8,5 |
# | **Churn (usuarios perdidos/mes)** | 75 | 120 |
# | **Coste de adquisición prorrateado (12 meses)** | 12 500 € | 12 500 € |
# | **Flujo neto mensual (operativo – CAC prorrateado)** | 2 500 € – 12 500 € = **‑10 000 €** | 3 200 € – 12 500 € = **‑9 300 €** |
#
# ### Qué nos dice la tabla
#
# 1. **Ingresos y beneficio operativo** aumentan ligeramente (≈ 5 % de ingresos, 28 % de beneficio operativo) porque la mayor cantidad de usuarios premium compensa la caída del precio.
# 2. **LTV disminuye** de 193 € a 127 €, ya que cada cliente paga menos y la retención se mantiene igual.
# 3. **Ratio LTV/CAC** sigue siendo > 1 (8,5) pero se reduce notablemente, lo que indica menor “margen de seguridad”.
# 4. **Churn absoluto** sube de 75 a 120 usuarios/mes, lo que implica mayor rotación y mayor carga de trabajo para re‑activar o reemplazar clientes.
# 5. **Flujo neto mensual (incluyendo CAC amortizado)** sigue negativo en ambos casos, pero la pérdida es un 7 % menor en el escenario propuesto.
#
# ---
#
# ## 4. Factores adicionales a considerar
#
# | Factor | Impacto potencial | Comentario |
# |--------|-------------------|------------|
# | **Elasticidad de la demanda** | Si la reducción de precio genera una conversión mayor que la estimada (p.ej. > 8 %), los ingresos podrían subir más. | Necesario validar con pruebas A/B. |
# | **Efecto sobre la percepción de valor** | Un precio más bajo puede devaluar la oferta premium y dificultar futuros aumentos de precio. | Riesgo a medio‑largo plazo. |
# | **Costos de soporte y servicio** | Más usuarios premium → mayor carga de soporte, posibles incrementos de costos operativos (no contemplados). | Revisar capacidad del equipo. |
# | **Cross‑sell / upsell** | Con más usuarios premium, se pueden vender add‑ons, formación, etc., que aumenten ARPU. | Oportunidad de compensar la caída del precio base. |
# | **Lifetime real vs. estimado** | La retención del 85 % puede cambiar al bajar el precio (posiblemente mejore, pero también podría empeorar si los usuarios perciben menos valor). | Medir en piloto. |
# | **Competencia** | Si la competencia ya ofrece precios similares, la reducción puede ser necesaria para mantener cuota de mercado. | Análisis de mercado. |
# | **Estrategia de crecimiento** | Si el objetivo es escalar rápidamente la base de premium, sacrificar margen a corto plazo puede ser aceptable. | Depende de la disponibilidad de capital. |
# | **Financiamiento** | Si la startup necesita generar cash‑flow positivo pronto, la reducción no ayuda mucho (aún negativo). | Evaluar necesidad de inversión externa. |
#
# ---
#
# ## 5. Recomendación fundamentada
#
# ### Síntesis cuantitativa
# - **Ingresos mensuales** subirían solo 4,8 % (de 14 500 € a 15 200 €).
# - **Beneficio operativo** aumentaría 28 % (de 2 500 € a 3 200 €), pero sigue siendo bajo frente a los costos fijos.
# - **LTV** caería un 34 % (de 193 € a 127 €), reduciendo considerablemente el margen de rentabilidad por cliente.
# - **Ratio LTV/CAC** seguiría siendo > 1 (8,5), pero mucho menos robusto que 12,9.
# - **Flujo neto mensual** (incluyendo CAC amortizado) seguiría negativo, aunque la pérdida sería ligeramente menor (‑9 300 € vs. ‑10 000 €).
#
# ### Evaluación cualitativa
# - La reducción de precio **no genera un salto significativo de ingresos**; la mayor conversión compensa apenas la caída del ARPU.
# - Se **pierde valor percibido** y se reduce la capacidad de monetizar a futuro (up‑sell, precios premium).
# - **Mayor churn absoluto** implica mayor presión operativa y de adquisición para mantener la base.
# - Si el objetivo principal es **crecer rápidamente la base premium** (por ejemplo, para atraer inversores o alcanzar un umbral de usuarios), la medida puede ser justificable, siempre que exista un plan para **incrementar ARPU** (add‑ons, precios escalonados) o **reducir costos**.
# - Si la prioridad es **generar cash‑flow positivo** o **maximizar rentabilidad**, la reducción de precio no es la mejor opción; la empresa seguiría operando con pérdidas y con un margen de seguridad menor.
#
# ### Recomendación
#
# > **No se recomienda implementar de forma permanente la reducción del precio a 19 €/mes bajo los supuestos actuales.**
#
# En su lugar, se sugiere:
#
# 1. **Realizar un test A/B** limitado (por ejemplo, 10 % de la base) para validar la verdadera tasa de conversión y el impacto en retención y churn.
# 2. **Explorar alternativas de aumento de ARPU** sin bajar el precio base:
#    - Introducir paquetes “premium + features” a 39 €/mes.
#    - Ofrecer suscripciones anuales con descuento (ej. 299 €/año) que aumenten la vida útil del cliente.
#    - Implementar un modelo freemium con micro‑transacciones (add‑ons, créditos).
# 3. **Optimizar el CAC**: si se logra reducir el coste de adquisición (p.ej. mediante marketing de referencia o contenido orgánico), el LTV/CAC mejorará sin necesidad de bajar precios.
# 4. **Revisar costos operativos**: automatizar soporte, usar SaaS de bajo coste, etc., para que el beneficio operativo sea mayor y reduzca la dependencia de precios.
#
# Si, después del test, la conversión supera ampliamente el 8 % (por ejemplo, > 12 %) y la retención mejora, entonces la reducción de precio podría reconsiderarse como una estrategia de **penetración de mercado**. De lo contrario, mantener el precio actual (29 €/mes) y trabajar en los puntos anteriores será la vía más rentable.
#
# === COMPLETITUD DEL ANÁLISIS ===
# ✓ Elementos clave cubiertos: 8/8
# ✓ Análisis completo: Sí

# %% [markdown]
# ## Técnicas Avanzadas de CoT

# %%
# Técnica 1: CoT con Auto-Verificación
def cot_con_verificacion():
    print("=== CoT CON AUTO-VERIFICACIÓN ===")
    
    problema = "Una piscina se llena con dos bombas. La bomba A la llena en 4 horas, la bomba B en 6 horas. Si funcionan juntas, ¿en cuánto tiempo llenan la piscina?"
    
    prompt_verificacion = f"""Resuelve este problema paso a paso y luego verifica tu respuesta:
    
{problema}
    
PASO 1 - RESOLUCIÓN:
Piensa paso a paso para encontrar la solución.
    
PASO 2 - VERIFICACIÓN:
Revisa tu cálculo usando un método diferente o verificando que los números tienen sentido.
    
PASO 3 - RESPUESTA FINAL:
Confirma tu respuesta final.
    
Proceso completo:"""
    
    try:
        response = llm.invoke([HumanMessage(content=prompt_verificacion)])
        print("PROBLEMA:")
        print(problema)
        print("\nSOLUCIÓN CON AUTO-VERIFICACIÓN:")
        print(response.content)
        
        # Verificar estructura
        contenido = response.content.lower()
        tiene_resolucion = 'paso 1' in contenido or 'resolución' in contenido
        tiene_verificacion = 'paso 2' in contenido or 'verificación' in contenido
        tiene_final = 'paso 3' in contenido or 'final' in contenido
        
        print("\n=== ESTRUCTURA ===")
        print(f"✓ Resolución: {'Sí' if tiene_resolucion else 'No'}")
        print(f"✓ Verificación: {'Sí' if tiene_verificacion else 'No'}")
        print(f"✓ Respuesta final: {'Sí' if tiene_final else 'No'}")
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar CoT con verificación
cot_con_verificacion()
# Out:
# === CoT CON AUTO-VERIFICACIÓN ===
# PROBLEMA:
# Una piscina se llena con dos bombas. La bomba A la llena en 4 horas, la bomba B en 6 horas. Si funcionan juntas, ¿en cuánto tiempo llenan la piscina?
#
# SOLUCIÓN CON AUTO-VERIFICACIÓN:
# **PASO 1 – RESOLUCIÓN**
#
# 1. **Determinar la tasa de llenado de cada bomba**
#    - La bomba A llena la piscina en 4 h → su tasa es
#      \[
#      r_A=\frac{1\ \text{piscina}}{4\ \text{h}}= \frac{1}{4}\ \text{piscina/hora}.
#      \]
#    - La bomba B llena la piscina en 6 h → su tasa es
#      \[
#      r_B=\frac{1}{6}\ \text{piscina/hora}.
#      \]
#
# 2. **Sumar las tasas cuando trabajan juntas**
#    \[
#    r_{\text{total}} = r_A + r_B = \frac{1}{4} + \frac{1}{6}.
#    \]
#
# 3. **Calcular la suma** (usar denominador común 12):
#    \[
#    \frac{1}{4} = \frac{3}{12},\qquad \frac{1}{6}= \frac{2}{12}.
#    \]
#    Entonces
#    \[
#    r_{\text{total}} = \frac{3}{12} + \frac{2}{12}= \frac{5}{12}\ \text{piscina/hora}.
#    \]
#
# 4. **Obtener el tiempo necesario** (tiempo = cantidad / tasa). Como la cantidad a llenar es 1 piscina:
#    \[
#    t = \frac{1\ \text{piscina}}{r_{\text{total}}}= \frac{1}{5/12}= \frac{12}{5}\ \text{h}.
#    \]
#
# 5. **Convertir a horas y minutos**
#    \[
#    \frac{12}{5}\ \text{h}= 2.4\ \text{h}= 2\ \text{h} + 0.4\ \text{h}.
#    \]
#    \(0.4\ \text{h}\times 60\ \text{min/h}=24\ \text{min}\).
#
#    **Tiempo conjunto = 2 h 24 min.**
#
# ---
#
# **PASO 2 – VERIFICACIÓN**
#
# *Método alternativo: usar fracciones de la piscina que se llenan por hora.*
#
# - En 1 h, A llena \( \frac{1}{4}=0.25\) de la piscina.
# - En 1 h, B llena \( \frac{1}{6}\approx0.1667\) de la piscina.
#
# Sumando: \(0.25+0.1667 = 0.4167\) de la piscina por hora.
#
# - Cuántas horas se necesitan para llegar a 1 piscina?
#   \[
#   \frac{1}{0.4167}\approx 2.4\ \text{h}=2\ \text{h}\ 24\ \text{min}.
#   \]
#
# *Comprobación directa con el tiempo hallado:*
#
# - En 2 h 24 min = 2.4 h, la bomba A aporta:
#   \[
#   2.4 \times \frac{1}{4}=0.6\ (\text{60 % de la piscina}).
#   \]
# - La bomba B aporta:
#   \[
#   2.4 \times \frac{1}{6}=0.4\ (\text{40 % de la piscina}).
#   \]
# - Suma: \(0.6+0.4 = 1.0\) → la piscina queda completa.
#
# Los cálculos coinciden, por lo que la respuesta es consistente.
#
# ---
#
# **PASO 3 – RESPUESTA FINAL**
#
# Cuando las bombas A (4 h) y B (6 h) funcionan simultáneamente, llenan la piscina en
#
# \[
# \boxed{2\ \text{horas}\ 24\ \text{minutos}}\;(= \frac{12}{5}\ \text{h}).
# \]
#
# === ESTRUCTURA ===
# ✓ Resolución: Sí
# ✓ Verificación: Sí
# ✓ Respuesta final: Sí

# %%
# Técnica 2: CoT Multi-Perspectiva
def cot_multi_perspectiva():
    print("=== CoT MULTI-PERSPECTIVA ===")
    
    dilema = """Una empresa de delivery está considerando implementar un algoritmo de IA 
    para optimizar rutas que podría reducir costos en 20% pero eliminaría 100 empleos 
    de repartidores. ¿Debería implementarlo?"""
    
    prompt_multi = f"""Analiza este dilema desde múltiples perspectivas:
    
{dilema}
    
Analiza paso a paso desde cada perspectiva:
    
PERSPECTIVA 1 - FINANCIERA:
- Beneficios económicos
- Costos de implementación
- ROI a corto y largo plazo
    
PERSPECTIVA 2 - SOCIAL/ÉTICA:
- Impacto en empleados
- Responsabilidad social corporativa
- Percepción pública
    
PERSPECTIVA 3 - ESTRATÉGICA:
- Competitividad del mercado
- Innovación tecnológica
- Sostenibilidad del negocio
    
SÍNTESIS:
- Integra las perspectivas
- Propone soluciones alternativas
- Recomienda curso de acción
    
Análisis completo:"""
    
    try:
        response = llm.invoke([HumanMessage(content=prompt_multi)])
        print("DILEMA EMPRESARIAL:")
        print(dilema)
        print("\nANÁLISIS MULTI-PERSPECTIVA:")
        print(response.content)
        
        # Verificar cobertura de perspectivas
        analisis = response.content.lower()
        perspectivas = ['financiera', 'social', 'ética', 'estratégica', 'síntesis']
        perspectivas_cubiertas = sum(1 for p in perspectivas if p in analisis)
        
        print(f"\n=== COBERTURA DEL ANÁLISIS ===")
        print(f"✓ Perspectivas cubiertas: {perspectivas_cubiertas}/{len(perspectivas)}")
        print(f"✓ Análisis integral: {'Sí' if perspectivas_cubiertas >= 4 else 'Parcial'}")
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar análisis multi-perspectiva
cot_multi_perspectiva()
# Out:
# === CoT MULTI-PERSPECTIVA ===
# DILEMA EMPRESARIAL:
# Una empresa de delivery está considerando implementar un algoritmo de IA
#     para optimizar rutas que podría reducir costos en 20% pero eliminaría 100 empleos
#     de repartidores. ¿Debería implementarlo?
#
# ANÁLISIS MULTI-PERSPECTIVA:
# ## Análisis paso a paso
#
# ### PERSPECTIVA 1 – FINANCIERA
#
# | Elemento | Detalle | Comentario |
# |----------|---------|------------|
# | **Beneficios económicos** | - Reducción de costos operativos en **≈ 20 %** (combustible, tiempo de trabajo, mantenimiento). <br>- Posible disminución de precios al cliente → mayor volumen de pedidos. <br>- Mejora del margen bruto que puede traducirse en mayor rentabilidad para accionistas. | El ahorro directo se traduce en **millones** de dólares anuales (dependiendo del tamaño de la flota). |
# | **Costos de implementación** | - Desarrollo o licenciamiento del algoritmo (IA/ML, datos de tráfico, integración con sistemas de gestión). <br>- Infraestructura tecnológica (servidores, cloud, sensores GPS, dispositivos IoT). <br>- Capacitación del personal de logística y de TI. <br>- Costos de transición (despidos, indemnizaciones, posible contratación de consultores). | Estimación típica: 5‑10 % del ahorro anual durante los **primeros 2‑3 años**. Si el ahorro anual es $10 M, la inversión inicial podría estar entre $0.5 M y $1 M, más costos de indemnización por 100 empleados (≈ $2‑3 M según legislación local). |
# | **ROI a corto plazo (1‑2 años)** | - **Ahorro neto** = ahorro operativo – costos de implementación – indemnizaciones. <br>- En muchos casos, el ROI puede ser **positivo** ya en el **primer año** si la empresa tiene alta densidad de pedidos y la IA es eficaz. | Sin embargo, el impacto de la pérdida de 100 empleados puede generar costos ocultos (riesgo de hueltas, pérdida de conocimiento operativo). |
# | **ROI a largo plazo (3‑5 años)** | - Consolidación de la ventaja competitiva → mayor cuota de mercado. <br>- Reducción de gastos fijos (menos salarios, seguros, beneficios). <br>- Posibilidad de escalar el algoritmo a nuevas ciudades o a otros servicios (p.ej., entregas de mercancía pesada). | ROI acumulado suele ser **muy favorable** (> 200 % en 5 años) siempre que la empresa mantenga la calidad del servicio. |
#
# ---
#
# ### PERSPECTIVA 2 – SOCIAL / ÉTICA
#
# | Aspecto | Impacto | Consideraciones |
# |---------|---------|-----------------|
# | **Impacto en empleados** | - **Desempleo** de 100 repartidores (posible pérdida de ingresos para familias). <br>- Erosión de la confianza interna y aumento del estrés entre el resto del personal. | - Obligación legal de indemnizar y ofrecer paquetes de recolocación. <br>- Riesgo de daño reputacional si se percibe como “despido masivo”. |
# | **Responsabilidad social corporativa (RSC)** | - La empresa tiene un deber implícito de **cuidar a sus trabajadores** y a la comunidad donde opera. <br>- La automatización sin una estrategia de transición puede ser vista como irresponsable. | - Programas de **re‑capacitación** (p.ej., conductores de vehículos eléctricos, gestión de flotas, atención al cliente). <br>- **Alianzas** con ONGs o gobiernos locales para crear oportunidades de empleo alternativo. |
# | **Percepción pública** | - **Clientes** pueden valorar la eficiencia y precios bajos, pero también pueden reaccionar negativamente ante la noticia de despidos masivos. <br>- **Medios** y **activistas** pueden criticar la “deshumanización” del trabajo. | - Comunicación transparente: explicar **por qué** se implementa la IA (sostenibilidad, precios más bajos) y **qué** se hará por los empleados afectados. <br>- Mostrar **compromiso** con la comunidad (p.ej., inversión en programas de movilidad urbana). |
# | **Equidad y justicia distributiva** | - El beneficio económico (menor precio, mayor rentabilidad) se concentra en accionistas y consumidores, mientras que el costo laboral recae en los trabajadores. | - Evaluar **compensaciones** (bonos, participación en utilidades) para los empleados que permanezcan. <br>- Considerar **modelos híbridos** donde parte de la flota siga siendo humana. |
#
# ---
#
# ### PERSPECTIVA 3 – ESTRATÉGICA
#
# | Factor | Implicación | Comentario |
# |--------|-------------|------------|
# | **Competitividad del mercado** | - Competidores que ya usan IA pueden ofrecer entregas más rápidas y precios menores. <br>- No adoptar la tecnología podría significar **pérdida de cuota**. | La ventaja competitiva se vuelve **temporal**; la IA pronto será estándar. |
# | **Innovación tecnológica** | - Implementar IA posiciona a la empresa como **líder** en transformación digital. <br>- Genera datos valiosos (patrones de demanda, comportamiento del tráfico) que pueden alimentar nuevos servicios (p.ej., predicción de demanda, ofertas dinámicas). | La inversión en IA abre puertas a **modelos de negocio** adicionales (logística como servicio, venta de datos anónimos). |
# | **Sostenibilidad del negocio** | - Rutas más óptimas reducen **emisiones de CO₂**, alineándose con objetivos ESG (Environmental, Social, Governance). <br>- Menor consumo de combustible → menor exposición a precios volátiles del petróleo. | La sostenibilidad puede atraer **inversores ESG** y mejorar la valoración de la empresa. |
# | **Riesgos estratégicos** | - Dependencia tecnológica → vulnerabilidad a fallos de algoritmo, ciberataques. <br>- Posible **reacción regulatoria** (leyes de protección al empleo, requisitos de transparencia algorítmica). | Necesario establecer **gobernanza de IA** (auditorías, explicabilidad). |
# | **Cultura organizacional** | - Cambio abrupto puede generar resistencia interna. <br>- Necesidad de **liderazgo** que gestione la transición cultural. | Un plan de cambio bien estructurado (Comunicación, Capacitación, Incentivos) es clave. |
#
# ---
#
# ## SÍNTESIS
#
# ### 1. Integración de perspectivas
#
# | Área | Convergencia | Tensión |
# |------|--------------|---------|
# | **Finanzas** | El proyecto promete **ahorro significativo** y **alto ROI**. | Los costos de indemnización y posibles sanciones sociales pueden reducir el beneficio neto a corto plazo. |
# | **Social/Ética** | La automatización puede contribuir a la **sostenibilidad** y a precios más bajos para la sociedad. | El **desempleo** de 100 personas genera un **costo humano** y reputacional que la empresa no puede ignorar. |
# | **Estratégica** | Adoptar IA es casi **inevitable** para mantener la competitividad y cumplir metas ESG. | La **dependencia tecnológica** y la posible reacción negativa del mercado laboral pueden afectar la marca. |
#
# En conjunto, la decisión no es simplemente “sí o no”. El reto es **maximizar el valor económico** mientras **mitiga el daño social** y **refuerza la posición estratégica**.
#
# ### 2. Soluciones alternativas
#
# | Alternativa | Descripción | Ventajas | Desventajas / Costos |
# |-------------|-------------|----------|----------------------|
# | **A) Implementación gradual + recolocación** | - Introducir IA en **solo el 30‑40 %** de la flota inicialmente. <br>- Ofrecer a los 100 repartidores **programas de re‑capacitación** para roles de soporte (monitor de flota, atención al cliente, mantenimiento de vehículos eléctricos). | - Reduce el choque social. <br>- Permite validar el algoritmo antes de escalar. | - Ahorro inicial menor (≈ 8 %). <br>- Costos de capacitación y gestión de transición. |
# | **B) Modelo híbrido “IA + humano”** | - Mantener una **parte de la flota** (p.ej., 60 %) operada por humanos en zonas de alta complejidad donde la IA es menos eficaz. <br>- Usar IA para **optimizar** rutas de los humanos, no para sustituirlos totalmente. | - Preserva empleo. <br>- Mejora la calidad del servicio en áreas complejas. | - Ahorro menor que la sustitución total. |
# | **C) Creación de “fondos de transición”** | - Destinar una parte del ahorro (p.ej., 5 % del ahorro anual) a un **fondo de apoyo** para los trabajadores despedidos (becas, microcréditos, incubadora de negocios). | - Mejora la percepción pública. <br>- Reduce riesgos de litigios y protestas. | - Reduce el ROI neto. |
# | **D) Externalización del impacto** | - Subcontratar la gestión de la IA a una **startup** que asuma parte del riesgo y comparta beneficios. | - Menor inversión de CAPEX. <br>- Acceso a expertise. | - Dependencia externa, menor control. |
# | **E) No implementar** | - Mantener la operación actual. | - Preserva empleo y reputación a corto plazo. | - Riesgo de quedar rezagado frente a competidores; pérdida de margen a medio‑largo plazo. |
#
# ### 3. Recomendación de curso de acción
#
# 1. **Adoptar una estrategia híbrida (Alternativa B) con fase piloto**
#    - **Fase 1 (0‑12 meses):** Implementar IA en el **30 %** de la flota que opera en rutas de alta densidad y baja complejidad.
#    - **Fase 2 (12‑24 meses):** Evaluar resultados (ahorro real, calidad del servicio, aceptación del cliente).
#    - **Fase 3 (24‑36 meses):** Expandir gradualmente hasta alcanzar **≈ 70 %** de automatización, manteniendo una capa humana para zonas críticas y como “backup”.
#
# 2. **Programa de recolocación y capacitación**
#    - Ofrecer **cursos de certificación** en gestión de flotas, análisis de datos, mantenimiento de vehículos eléctricos y atención al cliente.
#    - Garantizar **prioridad de empleo** en los nuevos roles creados por la expansión tecnológica.
#
# 3. **Fondo de transición social**
#    - Destinar **3‑5 %** del ahorro anual a un fondo que cubra **indemnizaciones, becas y apoyo a emprendimientos** de los trabajadores afectados.
#
# 4. **Comunicación y gobernanza**
#    - Lanzar una campaña de **transparencia** explicando los beneficios para clientes, empleados y la comunidad.
#    - Crear un **comité de ética de IA** interno (incluye representantes de RR.HH., legal, tecnología y empleados) que supervise la implementación y gestione riesgos de sesgo y privacidad.
#
# 5. **Monitoreo de indicadores clave (KPIs)**
#
# | KPI | Meta (3 años) |
# |-----|---------------|
# | Reducción de costos operativos | **≥ 15 %** (objetivo final 20 %) |
# | Índice de satisfacción del cliente (NPS) | **≥ +10** puntos |
# | Tasa de recolocación de empleados despedidos | **≥ 80 %** dentro de 12 meses |
# | Emisiones de CO₂ por entrega | **↓ 25 %** respecto a la línea base |
# | ROI acumulado | **> 150 %** |
#
# ---
#
# ## Conclusión
#
# - **Financieramente** la IA es atractiva y casi indispensable para mantener la competitividad a medio‑largo plazo.
# - **Socialmente**, la empresa tiene la obligación de mitigar el impacto negativo sobre los 100 repartidores; la falta de acción puede generar costos reputacionales y regulatorios mayores que los ahorros.
# - **Estratégicamente**, la adopción temprana de IA posiciona a la compañía como líder en innovación y sostenibilidad, pero debe acompañarse de una gestión del cambio robusta.
#
# **Recomendación final:** Implementar la IA de forma **gradual y combinada con un programa integral de transición laboral**, garantizando que los beneficios económicos se compartan con los empleados y la comunidad. De este modo, la empresa maximiza su ROI, protege su reputación y cumple con sus responsabilidades éticas y estratégicas.
#
# === COBERTURA DEL ANÁLISIS ===
# ✓ Perspectivas cubiertas: 5/5
# ✓ Análisis integral: Sí

# %% [markdown]
# ## CoT para Debugging de Código
#
# Una aplicación práctica muy útil: usar CoT para analizar y debuggear código.

# %%
# CoT para debugging de código
def cot_debugging():
    print("=== CoT PARA DEBUGGING DE CÓDIGO ===")
    
    codigo_con_bug = '''def calcular_promedio(numeros):
    total = 0
    for numero in numeros:
        total += numero
    promedio = total / len(numeros)
    return promedio

# Uso
datos = []
resultado = calcular_promedio(datos)
print(f"El promedio es: {resultado}")'''
    
    prompt_debugging = f"""Analiza este código paso a paso para encontrar problemas:
    
```python
{codigo_con_bug}
```
    
PASO 1 - COMPRENSIÓN:
¿Qué se supone que hace este código?
    
PASO 2 - ANÁLISIS LÍNEA POR LÍNEA:
Examina cada línea en busca de problemas potenciales.
    
PASO 3 - IDENTIFICACIÓN DE PROBLEMAS:
¿Qué errores o problemas específicos encuentras?
    
PASO 4 - CASOS PROBLEMÁTICOS:
¿En qué situaciones fallaría este código?
    
PASO 5 - SOLUCIÓN:
¿Cómo arreglarías estos problemas?
    
Análisis de debugging:"""
    
    try:
        response = llm.invoke([HumanMessage(content=prompt_debugging)])
        print("CÓDIGO A ANALIZAR:")
        print(codigo_con_bug)
        print("\nANÁLISIS DE DEBUGGING:")
        print(response.content)
        
        # Verificar si encontró el problema principal
        analisis = response.content.lower()
        encontro_division_cero = any(term in analisis for term in ['división', 'cero', 'vacía', 'empty'])
        propuso_solucion = 'if' in analisis or 'len(' in analisis or 'excepción' in analisis
        
        print(f"\n=== EFECTIVIDAD DEL DEBUGGING ===")
        print(f"✓ Identificó división por cero: {'Sí' if encontro_division_cero else 'No'}")
        print(f"✓ Propuso solución: {'Sí' if propuso_solucion else 'No'}")
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar debugging
cot_debugging()
# Out:
# === CoT PARA DEBUGGING DE CÓDIGO ===
# CÓDIGO A ANALIZAR:
# def calcular_promedio(numeros):
#     total = 0
#     for numero in numeros:
#         total += numero
#     promedio = total / len(numeros)
#     return promedio
#
# # Uso
# datos = []
# resultado = calcular_promedio(datos)
# print(f"El promedio es: {resultado}")
#
# ANÁLISIS DE DEBUGGING:
# **PASO 1 – COMPRENSIÓN**
# El fragmento define una función `calcular_promedio` que recibe una lista (u otro iterable) de números, suma todos sus elementos y devuelve la media aritmética (`total / len(numeros)`). Después se crea una lista vacía `datos`, se llama a la función con esa lista y se imprime el resultado.
#
# ---
#
# **PASO 2 – ANÁLISIS LÍNEA POR LÍNEA**
#
# | Línea | Qué hace | Posibles problemas |
# |-------|----------|--------------------|
# | `def calcular_promedio(numeros):` | Declara la función. | Ninguno. |
# | `    total = 0` | Inicializa el acumulador. | Ninguno. |
# | `    for numero in numeros:` | Recorre cada elemento. | Si `numeros` no es iterable → `TypeError`. |
# | `        total += numero` | Suma cada elemento al acumulador. | Si algún elemento no es numérico → `TypeError`. |
# | `    promedio = total / len(numeros)` | Calcula la media dividiendo por la longitud. | **División por cero** cuando `numeros` está vacío; `len` también falla si `numeros` no tiene longitud (p.ej. un generador sin `len`). |
# | `    return promedio` | Devuelve el valor calculado. | Ninguno. |
# | `datos = []` | Lista vacía. | No hay problema en sí, pero al pasarla a la función provocará el error anterior. |
# | `resultado = calcular_promedio(datos)` | Llamada a la función. | Generará `ZeroDivisionError`. |
# | `print(f"El promedio es: {resultado}")` | Imprime el resultado. | No se ejecutará si la llamada anterior lanza excepción. |
#
# ---
#
# **PASO 3 – IDENTIFICACIÓN DE PROBLEMAS**
#
# 1. **División por cero**: Cuando `numeros` está vacío (`len(numeros) == 0`), la línea `total / len(numeros)` lanza `ZeroDivisionError`.
# 2. **Falta de validación de tipos**:
#    - Si `numeros` no es iterable → `TypeError`.
#    - Si algún elemento no es numérico (p.ej. `str`) → `TypeError` al intentar `total += numero`.
# 3. **No se manejan colecciones que no implementan `len`** (como generadores). `len` fallará con `TypeError`.
# 4. **No hay documentación ni anotaciones de tipo** que ayuden al usuario a saber qué se espera.
# 5. **No se controla la precisión** (p.ej. división entera en Python 2, aunque en Python 3 siempre es flotante, pero sigue siendo buena práctica convertir a `float`).
# 6. **El nombre de la variable `datos` está vacío**; aunque no es un error, puede confundir al leer el código.
#
# ---
#
# **PASO 4 – CASOS PROBLEMÁTICOS**
#
# | Caso | Qué ocurre |
# |------|------------|
# | `calcular_promedio([])` | `ZeroDivisionError: division by zero`. |
# | `calcular_promedio([1, 2, 'tres'])` | `TypeError` al intentar `total += 'tres'`. |
# | `calcular_promedio(None)` | `TypeError: 'NoneType' object is not iterable`. |
# | `calcular_promedio((x for x in []))` (generador) | `TypeError` en `len(numeros)`. |
# | `calcular_promedio('123')` | Se iterará carácter por carácter, sumando códigos Unicode → resultado inesperado o `TypeError` si se intenta sumar `int` y `str`. |
# | `calcular_promedio([1, 2, 3.5])` | Funciona, pero si se desea siempre un `float` se debería asegurar la conversión. |
#
# ---
#
# **PASO 5 – SOLUCIÓN**
#
# A continuación una versión robusta que:
#
# * Valida que el argumento sea iterable y no vacío.
# * Convierte cada elemento a `float` (o lanza error claro si no es convertible).
# * Soporta cualquier iterable (incluidos generadores) sin depender de `len`.
# * Documenta la función y usa anotaciones de tipo.
#
# ```python
# from collections.abc import Iterable
# from typing import Iterable as TypingIterable, Union, List
#
# def calcular_promedio(
#     numeros: TypingIterable[Union[int, float]]
# ) -> float:
#     """
#     Calcula el promedio (media aritmética) de una colección de números.
#
#     Parámetros
#     ----------
#     numeros : iterable de int o float
#         Colección que contiene los valores a promediar. Puede ser una lista,
#         tupla, generador, etc.
#
#     Returns
#     -------
#     float
#         El promedio de los valores.
#
#     Raises
#     ------
#     ValueError
#         Si la colección está vacía.
#     TypeError
#         Si `numeros` no es iterable o contiene elementos no numéricos.
#     """
#     # 1️⃣ Verificar que sea iterable
#     if not isinstance(numeros, Iterable):
#         raise TypeError("El argumento debe ser un iterable de números.")
#
#     total = 0.0
#     contador = 0
#
#     for elemento in numeros:
#         try:
#             valor = float(elemento)          # permite int, float, str numérico, etc.
#         except (TypeError, ValueError) as exc:
#             raise TypeError(
#                 f"Elemento no convertible a número: {elemento!r}"
#             ) from exc
#
#         total += valor
#         contador += 1
#
#     if contador == 0:
#         raise ValueError("No se puede calcular el promedio de una colección vacía.")
#
#     return total / contador
# ```
#
# **Uso seguro**
#
# ```python
# # Caso normal
# datos = [4, 8, 15, 16, 23, 42]
# print(f"El promedio es: {calcular_promedio(datos)}")
#
# # Caso con generador
# generador = (x for x in range(1, 6))   # 1..5
# print(f"Promedio del generador: {calcular_promedio(generador)}")
#
# # Manejo de errores
# try:
#     print(calcular_promedio([]))
# except ValueError as e:
#     print(f"Error: {e}")
#
# try:
#     print(calcular_promedio([1, 'dos', 3]))
# except TypeError as e:
#     print(f"Error: {e}")
# ```
#
# **Resumen de mejoras**
#
# | Problema original | Solución implementada |
# |-------------------|-----------------------|
# | División por cero | Se cuenta cuántos elementos se procesan y se lanza `ValueError` si es 0. |
# | Argumento no iterable | Chequeo explícito `isinstance(..., Iterable)` y `TypeError` descriptivo. |
# | Elementos no numéricos | Conversión a `float` dentro de `try/except` con mensaje claro. |
# | No funciona con generadores | No se usa `len`; se cuenta manualmente mientras se itera. |
# | Falta de documentación | Docstring completa y anotaciones de tipo. |
# | Posible confusión de tipos de retorno | Siempre devuelve `float`. |
#
# Con estos cambios el código es a prueba de los casos problemáticos más comunes y resulta más fácil de mantener y reutilizar.
#
# === EFECTIVIDAD DEL DEBUGGING ===
# ✓ Identificó división por cero: Sí
# ✓ Propuso solución: Sí

# %% [markdown]
# # Ejercicio con Chain of Thought

# %%
# Ejercicio final: Diseña tu propio CoT prompt
def ejercicio_cot():
    print("=== EJERCICIO: DISEÑA TU CoT PROMPT ===")
    print("\nTarea: Crear un sistema CoT para análisis de inversión")
    print("\nEscenario:")
    print("Una persona tiene 10,000€ para invertir y está considerando tres opciones:")
    print("1. Acciones de tech (retorno esperado 12% anual, riesgo alto)")
    print("2. Bonos gubernamentales (retorno 3% anual, riesgo bajo)")
    print("3. Fondo mixto (retorno 7% anual, riesgo medio)")
    print("\nLa persona es joven (25 años) y puede asumir riesgo moderado.")
    
    # Template para el estudiante
    template_cot = """
    # TU PROMPT CoT AQUÍ:
    
    Analiza esta decisión de inversión paso a paso:
    
    [ESCENARIO]
    
    PASO 1 - PERFIL DEL INVERSOR:
    - Analiza edad, tolerancia al riesgo, horizonte temporal
    
    PASO 2 - ANÁLISIS DE OPCIONES:
    - Evalúa cada opción: retorno, riesgo, liquidez
    
    PASO 3 - ESTRATEGIA DE DIVERSIFICACIÓN:
    - Considera combinar opciones
    
    PASO 4 - RECOMENDACIÓN:
    - Proporciona recomendación específica con justificación
    
    Análisis de inversión:
    """
    
    print("\nDiseña un prompt CoT estructurado:")
    print(template_cot)
    
    # Prompt de ejemplo bien diseñado
    prompt_ejemplo = """Analiza esta decisión de inversión usando razonamiento paso a paso:
    
SITUACIÓN:
Inversor de 25 años con 10,000€ considerando:
- Acciones tech: 12% retorno anual, riesgo alto
- Bonos: 3% retorno anual, riesgo bajo  
- Fondo mixto: 7% retorno anual, riesgo medio
Tolerancia: riesgo moderado
    
PASO 1 - PERFIL DEL INVERSOR:
Analiza edad, horizonte temporal y tolerancia al riesgo.
    
PASO 2 - EVALUACIÓN DE OPCIONES:
Para cada opción, calcula:
- Valor esperado en 10 años
- Nivel de riesgo vs. perfil
- Pros y contras específicos
    
PASO 3 - ESTRATEGIA DE PORTFOLIO:
Considera distribución óptima entre opciones basada en:
- Diversificación de riesgo
- Maximización de retorno ajustado por riesgo
- Liquidez y flexibilidad
    
PASO 4 - RECOMENDACIÓN FINAL:
Proporciona distribución específica (porcentajes) con:
- Justificación detallada
- Proyección a 10 años
- Consideraciones adicionales
    
Análisis completo:"""
    
    print("\n=== PROMPT DE REFERENCIA ===")
    print(prompt_ejemplo)
    
    # Ejecutar el prompt ejemplo
    print("\n=== RESULTADO DEL ANÁLISIS ===")
    try:
        response = llm.invoke([HumanMessage(content=prompt_ejemplo)])
        print(response.content)
        
        # Análisis de la respuesta
        analisis = response.content.lower()
        elementos = ['perfil', 'evaluación', 'portfolio', 'recomendación', '%', '€', 'años']
        elementos_presentes = sum(1 for elem in elementos if elem in analisis)
        
        print(f"\n=== CALIDAD DEL ANÁLISIS ===")
        print(f"✓ Elementos clave: {elementos_presentes}/{len(elementos)}")
        print(f"✓ Análisis completo: {'Sí' if elementos_presentes >= 5 else 'Parcial'}")
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar ejercicio
ejercicio_cot()
# Out:
# === EJERCICIO: DISEÑA TU CoT PROMPT ===
#
# Tarea: Crear un sistema CoT para análisis de inversión
#
# Escenario:
# Una persona tiene 10,000€ para invertir y está considerando tres opciones:
# 1. Acciones de tech (retorno esperado 12% anual, riesgo alto)
# 2. Bonos gubernamentales (retorno 3% anual, riesgo bajo)
# 3. Fondo mixto (retorno 7% anual, riesgo medio)
#
# La persona es joven (25 años) y puede asumir riesgo moderado.
#
# Diseña un prompt CoT estructurado:
#
#     # TU PROMPT CoT AQUÍ:
#
#     Analiza esta decisión de inversión paso a paso:
#
#     [ESCENARIO]
#
#     PASO 1 - PERFIL DEL INVERSOR:
#     - Analiza edad, tolerancia al riesgo, horizonte temporal
#
#     PASO 2 - ANÁLISIS DE OPCIONES:
#     - Evalúa cada opción: retorno, riesgo, liquidez
#
#     PASO 3 - ESTRATEGIA DE DIVERSIFICACIÓN:
#     - Considera combinar opciones
#
#     PASO 4 - RECOMENDACIÓN:
#     - Proporciona recomendación específica con justificación
#
#     Análisis de inversión:
#
#
# === PROMPT DE REFERENCIA ===
# Analiza esta decisión de inversión usando razonamiento paso a paso:
#
# SITUACIÓN:
# Inversor de 25 años con 10,000€ considerando:
# - Acciones tech: 12% retorno anual, riesgo alto
# - Bonos: 3% retorno anual, riesgo bajo
# - Fondo mixto: 7% retorno anual, riesgo medio
# Tolerancia: riesgo moderado
#
# PASO 1 - PERFIL DEL INVERSOR:
# Analiza edad, horizonte temporal y tolerancia al riesgo.
#
# PASO 2 - EVALUACIÓN DE OPCIONES:
# Para cada opción, calcula:
# - Valor esperado en 10 años
# - Nivel de riesgo vs. perfil
# - Pros y contras específicos
#
# PASO 3 - ESTRATEGIA DE PORTFOLIO:
# Considera distribución óptima entre opciones basada en:
# - Diversificación de riesgo
# - Maximización de retorno ajustado por riesgo
# - Liquidez y flexibilidad
#
# PASO 4 - RECOMENDACIÓN FINAL:
# Proporciona distribución específica (porcentajes) con:
# - Justificación detallada
# - Proyección a 10 años
# - Consideraciones adicionales
#
# Análisis completo:
#
# === RESULTADO DEL ANÁLISIS ===
# **PASO 1 - PERFIL DEL INVERSOR**
#
# El inversor tiene 25 años, lo que indica un horizonte temporal largo para la inversión. Con 10,000€ disponibles para invertir y una tolerancia al riesgo moderada, este inversor puede considerar una estrategia de inversión que busque un equilibrio entre el crecimiento a largo plazo y la gestión del riesgo. La edad y el horizonte temporal sugieren que puede absorber algunas fluctuaciones del mercado a cambio de potenciales retornos más altos a largo plazo.
#
# **PASO 2 - EVALUACIÓN DE OPCIONES**
#
# 1. **Acciones Tech (12% retorno anual, riesgo alto)**
#    - **Valor esperado en 10 años**: Suponiendo un crecimiento constante del 12% anual, el valor esperado en 10 años sería aproximadamente 30,959€ (10,000 * (1 + 0.12)^10).
#    - **Nivel de riesgo vs. perfil**: El riesgo alto asociado con las acciones tech es más alto que la tolerancia moderada del inversor.
#    - **Pros y contras**: Pros - Alto potencial de crecimiento. Contras - Riesgo alto de pérdidas significativas.
#
# 2. **Bonos (3% retorno anual, riesgo bajo)**
#    - **Valor esperado en 10 años**: Con un crecimiento del 3% anual, el valor esperado en 10 años sería aproximadamente 13,425€ (10,000 * (1 + 0.03)^10).
#    - **Nivel de riesgo vs. perfil**: El riesgo bajo de los bonos se ajusta a la tolerancia al riesgo del inversor, pero puede ser demasiado conservador.
#    - **Pros y contras**: Pros - Estabilidad y seguridad. Contras - Retorno potencialmente bajo.
#
# 3. **Fondo Mixto (7% retorno anual, riesgo medio)**
#    - **Valor esperado en 10 años**: Con un crecimiento del 7% anual, el valor esperado en 10 años sería aproximadamente 19,672€ (10,000 * (1 + 0.07)^10).
#    - **Nivel de riesgo vs. perfil**: El riesgo medio del fondo mixto se ajusta bien a la tolerancia moderada del inversor.
#    - **Pros y contras**: Pros - Equilibrio entre crecimiento y riesgo. Contras - Retorno potencialmente inferior al de las acciones tech.
#
# **PASO 3 - ESTRATEGIA DE PORTFOLIO**
#
# Para maximizar el retorno ajustado por riesgo y considerando la diversificación, una estrategia podría ser combinar las opciones para equilibrar el riesgo y el potencial de crecimiento. Dado el perfil del inversor, una distribución que considere la tolerancia al riesgo moderada y el horizonte temporal largo podría ser:
#
# - **40% en Acciones Tech**: Para aprovechar el alto potencial de crecimiento a largo plazo, aunque con un riesgo alto.
# - **30% en Fondo Mixto**: Ofrece un equilibrio entre crecimiento y riesgo, ajustándose a la tolerancia moderada del inversor.
# - **30% en Bonos**: Para proporcionar estabilidad y seguridad, reduciendo el riesgo general del portafolio.
#
# **PASO 4 - RECOMENDACIÓN FINAL**
#
# **Distribución específica**: 40% Acciones Tech, 30% Fondo Mixto, 30% Bonos.
#
# **Justificación detallada**: Esta distribución busca equilibrar el crecimiento a largo plazo con la gestión del riesgo. Las acciones tech ofrecen alto potencial de crecimiento, el fondo mixto proporciona un equilibrio, y los bonos aportan estabilidad. Esta combinación se ajusta a la tolerancia al riesgo moderada del inversor y su horizonte temporal largo.
#
# **Proyección a 10 años**: La proyección exacta dependerá del desempeño real de cada inversión, pero esta distribución debería ofrecer un crecimiento significativo con un nivel de riesgo manejable. Suponiendo que cada activo cumpla con sus retornos esperados, el valor total del portafolio en 10 años podría estimarse como:
# - Acciones Tech (40% de 10,000€): 12,383€ (40% de 30,959€)
# - Fondo Mixto (30% de 10,000€): 5,901€ (30% de 19,672€)
# - Bonos (30% de 10,000€): 4,028€ (30% de 13,425€)
# Total: 22,312€
#
# **Consideraciones adicionales**: Es importante revisar y ajustar el portafolio periódicamente para asegurarse de que sigue alineado con los objetivos y la tolerancia al riesgo del inversor. La diversificación y la disciplina a largo plazo son clave para el éxito de esta estrategia de inversión.
#
# === CALIDAD DEL ANÁLISIS ===
# ✓ Elementos clave: 7/7
# ✓ Análisis completo: Sí

# %% [markdown]
# ## Limitaciones y Consideraciones de CoT
#
# ### ✅ Cuándo Usar CoT:
# - Problemas matemáticos complejos
# - Razonamiento lógico multi-paso
# - Análisis que requiere transparencia
# - Cuando necesitas verificar el proceso
# - Problemas donde el "por qué" es importante
#
# ### ⚠️ Limitaciones:
# - **Más tokens**: Respuestas más largas = mayor costo
# - **Tiempo**: Razonamiento paso a paso toma más tiempo
# - **Complejidad innecesaria**: Para problemas simples puede ser excesivo
# - **Razonamiento erróneo**: Puede mostrar lógica incorrecta convincente
#
# ### 🎯 Mejores Prácticas:
# 1. **Estructura clara**: Define pasos específicos
# 2. **Verificación**: Incluye auto-verificación cuando sea posible
# 3. **Ejemplos**: Usa few-shot para mostrar patrón deseado
# 4. **Temperatura baja**: Para razonamiento más consistente
# 5. **Validación externa**: Verifica respuestas críticas independientemente

# %% [markdown]
# ## Conceptos Clave Aprendidos
#
# 1. **Chain-of-Thought** mejora dramáticamente la precisión en problemas complejos
# 2. **Zero-shot CoT** es tan simple como agregar "piensa paso a paso"
# 3. **Few-shot CoT** combina ejemplos con razonamiento para mejor control
# 4. **Estructura explícita** guía el razonamiento hacia análisis completos
# 5. **Auto-verificación** aumenta la confiabilidad de las respuestas
#
# ## Próximos Pasos
#
# En el siguiente notebook exploraremos **Técnicas Avanzadas** como Tree of Thoughts (ToT), Self-Consistency, y otras metodologías cutting-edge que llevan el prompt engineering al siguiente nivel.
#
# ### Para Practicar:
# 1. Aplica CoT a problemas de tu dominio específico
# 2. Experimenta con diferentes niveles de estructura
# 3. Compara precisión con y sin CoT
# 4. Desarrolla patrones de verificación personalizados
