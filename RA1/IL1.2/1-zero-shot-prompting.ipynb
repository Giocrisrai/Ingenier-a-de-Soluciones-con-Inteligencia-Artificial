# %% [markdown]
# # 1. Zero-Shot Prompting - Prompts Sin Ejemplos Previos
#
# ## Objetivos de Aprendizaje
# - Comprender los principios del zero-shot prompting
# - Diseñar prompts efectivos sin ejemplos previos
# - Aplicar técnicas de instrucción clara y contexto
# - Evaluar la efectividad de diferentes enfoques zero-shot
#
# ## ¿Qué es Zero-Shot Prompting?
#
# Zero-shot prompting es la técnica donde pedimos al modelo realizar una tarea **sin proporcionar ejemplos específicos** de cómo debe hacerla. El modelo debe basarse únicamente en:
# - Su entrenamiento previo
# - Las instrucciones que le damos
# - El contexto que proporcionamos
#
# ### Ventajas:
# - **Simplicidad**: No requiere crear ejemplos
# - **Flexibilidad**: Fácil de adaptar a nuevas tareas
# - **Eficiencia**: Menos tokens utilizados
# - **Generalización**: Funciona para tareas diversas
#
# ### Limitaciones:
# - **Inconsistencia**: Resultados pueden variar más
# - **Formato**: Menos control sobre la estructura de salida
# - **Tareas complejas**: Puede requerir instrucciones muy detalladas
# - **Dominio específico**: Menos efectivo en nichos especializados

# %%
# Configuración inicial
import os

# Carga de credenciales: funciona igual en Google Colab y en local (.env)
try:
    from google.colab import userdata  # type: ignore
    os.environ["GROQ_API_KEY"] = userdata.get("GROQ_API_KEY")
except ImportError:
    from dotenv import load_dotenv
    load_dotenv()

assert os.getenv("GROQ_API_KEY"), "Falta GROQ_API_KEY (Colab: Secrets · local: archivo .env)"

MODELO = os.getenv("GROQ_MODEL", "llama-3.3-70b-versatile")

from langchain_groq import ChatGroq
from langchain_core.messages import HumanMessage, SystemMessage
import re
import time

# Configurar el modelo (ChatGroq lee GROQ_API_KEY del entorno automáticamente)
llm = ChatGroq(
    model=MODELO,
    temperature=0.7  # Balance entre creatividad y consistencia
)

print("✓ Modelo configurado para zero-shot prompting")
# Out:
# ✓ Modelo configurado para zero-shot prompting

# %% [markdown]
# ## Anatomía de un Prompt Zero-Shot Efectivo
#
# Un prompt zero-shot efectivo tiene estos componentes:
#
# 1. **Contexto/Rol**: Quién debe "ser" el modelo
# 2. **Tarea**: Qué debe hacer específicamente
# 3. **Formato**: Cómo debe estructurar la respuesta
# 4. **Restricciones**: Qué debe evitar o considerar
# 5. **Input**: Los datos específicos a procesar

# %%
# Ejemplo básico vs mejorado
def comparar_prompts_basico():
    texto = "El nuevo iPhone tiene una batería increíble y la cámara es fantástica, pero el precio es muy alto."
    
    # Prompt básico (menos efectivo)
    prompt_basico = f"Analiza este texto: {texto}"
    
    # Prompt mejorado (más efectivo)
    prompt_mejorado = f"""Eres un analista de sentimientos experto. 
    
Tarea: Analiza el sentimiento del siguiente texto sobre un producto.
    
Formato de respuesta:
- Sentimiento general: [Positivo/Negativo/Neutral]
- Aspectos positivos: [lista]
- Aspectos negativos: [lista]
- Puntuación de confianza: [0-10]
    
Texto a analizar: "{texto}"""
    
    print("=== COMPARACIÓN DE PROMPTS ===")
    
    # Probar prompt básico
    print("\n1. PROMPT BÁSICO:")
    print(f"Prompt: {prompt_basico}")
    try:
        response1 = llm.invoke([HumanMessage(content=prompt_basico)])
        print(f"Respuesta: {response1.content}")
    except Exception as e:
        print(f"Error: {e}")
    
    print("\n" + "-"*60)
    
    # Probar prompt mejorado
    print("\n2. PROMPT MEJORADO:")
    print(f"Prompt: {prompt_mejorado[:100]}...")
    try:
        response2 = llm.invoke([HumanMessage(content=prompt_mejorado)])
        print(f"Respuesta: {response2.content}")
    except Exception as e:
        print(f"Error: {e}")
    
    print("\n=== ANÁLISIS ===")
    print("• Prompt básico: Ambiguo, respuesta poco estructurada")
    print("• Prompt mejorado: Específico, respuesta estructurada y útil")

# Ejecutar comparación
comparar_prompts_basico()
# Out:
# === COMPARACIÓN DE PROMPTS ===
#
# 1. PROMPT BÁSICO:
# Prompt: Analiza este texto: El nuevo iPhone tiene una batería increíble y la cámara es fantástica, pero el precio es muy alto.
# Respuesta: Análisis del texto:
#
# **Contenido**: El texto habla sobre las características de un nuevo modelo de iPhone, específicamente sobre su batería y cámara. También menciona el precio del dispositivo.
#
# **Estructura**: El texto tiene una estructura simple, con una oración que presenta dos características positivas del iPhone (batería y cámara) y una característica negativa (precio alto).
#
# **Tono**: El tono del texto es neutral, aunque hay un matiz de crítica hacia el precio del dispositivo. La palabra "incredible" y "fantástica" sugieren una actitud positiva hacia las características del iPhone, mientras que "muy alto" sugiere una actitud negativa hacia el precio.
#
# **Lenguaje**: El lenguaje utilizado es informal y coloquial, con palabras como "increíble" y "fantástica" que son comunes en el lenguaje cotidiano. El texto no utiliza un lenguaje técnico o especializado.
#
# **Objetivo**: El objetivo del texto parece ser expresar una opinión personal sobre el nuevo iPhone, destacando sus características positivas y negativas. No parece tener un objetivo persuasivo o comercial.
#
# **Público**: El público al que se dirige el texto es probablemente cualquier persona interesada en tecnología o que esté considerando comprar un nuevo teléfono móvil.
#
# En resumen, el texto es una opinión personal y breve sobre el nuevo iPhone, que destaca sus características positivas y negativas de manera neutral y coloquial.
#
# ------------------------------------------------------------
#
# 2. PROMPT MEJORADO:
# Prompt: Eres un analista de sentimientos experto.
#
# Tarea: Analiza el sentimiento del siguiente texto sobre ...
# Respuesta: - Sentimiento general: Neutral
# - Aspectos positivos:
#   * La batería del iPhone es increíble
#   * La cámara es fantástica
# - Aspectos negativos:
#   * El precio del iPhone es muy alto
# - Puntuación de confianza: 8
#
# El sentimiento general del texto es neutral porque, aunque se mencionan aspectos positivos del producto como la batería y la cámara, también se destaca un aspecto negativo significativo, que es el precio alto. La confianza en el análisis es alta (8 de 10) porque el lenguaje utilizado es claro y directo, lo que facilita la identificación de los sentimientos expresados.
#
# === ANÁLISIS ===
# • Prompt básico: Ambiguo, respuesta poco estructurada
# • Prompt mejorado: Específico, respuesta estructurada y útil

# %% [markdown]
# ## Técnicas de Zero-Shot por Tipo de Tarea
#
# Diferentes tipos de tareas requieren enfoques específicos en zero-shot prompting.

# %%
# 1. CLASIFICACIÓN
def zero_shot_clasificacion():
    print("=== ZERO-SHOT PARA CLASIFICACIÓN ===")
    
    emails = [
        "Reunión de equipo mañana a las 10 AM en sala de conferencias",
        "¡Felicidades! Has ganado $1,000,000! Haz clic aquí ahora",
        "Recordatorio: Tu factura de internet vence en 3 días"
    ]
    
    # Prompt optimizado para clasificación
    clasificacion_prompt = """Eres un clasificador de emails empresariales.
    
Clasifica cada email en una de estas categorías:
- TRABAJO: Relacionado con tareas laborales
- SPAM: Contenido no solicitado o sospechoso
- PERSONAL: Asuntos personales o administrativos

Responde solo con el nombre de la categoría.

Email: "{}"
Categoría:"""
    
    for i, email in enumerate(emails, 1):
        prompt = clasificacion_prompt.format(email)
        try:
            response = llm.invoke([HumanMessage(content=prompt)])
            print(f"{i}. Email: {email[:50]}...")
            print(f"   Clasificación: {response.content.strip()}\n")
        except Exception as e:
            print(f"Error en email {i}: {e}")

# Ejecutar clasificación
zero_shot_clasificacion()
# Out:
# === ZERO-SHOT PARA CLASIFICACIÓN ===
# 1. Email: Reunión de equipo mañana a las 10 AM en sala de co...
#    Clasificación: TRABAJO
# 2. Email: ¡Felicidades! Has ganado $1,000,000! Haz clic aquí...
#    Clasificación: SPAM
# 3. Email: Recordatorio: Tu factura de internet vence en 3 dí...
#    Clasificación: PERSONAL

# %%
# 2. GENERACIÓN DE CONTENIDO
def zero_shot_generacion():
    print("=== ZERO-SHOT PARA GENERACIÓN ===")
    
    # Prompt estructurado para generación
    generacion_prompt = """Eres un copywriter creativo especializado en redes sociales.
    
Tarea: Crear un post para LinkedIn sobre el tema dado.
    
Requisitos:
- Tono profesional pero accesible
- Máximo 150 palabras
- Incluir 1-2 hashtags relevantes
- Hacer una pregunta para fomentar engagement
    
Tema: "Importancia del aprendizaje continuo en tecnología"
    
Post para LinkedIn:"""
    
    try:
        response = llm.invoke([HumanMessage(content=generacion_prompt)])
        print("Post generado:")
        print("-" * 40)
        print(response.content)
        print("-" * 40)
        
        # Análisis del resultado
        words = len(response.content.split())
        hashtags = response.content.count('#')
        questions = response.content.count('?')
        
        print(f"\nAnálisis:")
        print(f"• Palabras: {words} (límite: 150)")
        print(f"• Hashtags: {hashtags}")
        print(f"• Preguntas: {questions}")
        print(f"• Cumple requisitos: {'✓' if words <= 150 and hashtags >= 1 and questions >= 1 else '✗'}")
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar generación
zero_shot_generacion()
# Out:
# === ZERO-SHOT PARA GENERACIÓN ===
# Post generado:
# ----------------------------------------
# "En el mundo de la tecnología, el cambio es constante. Para mantenerse al día, es fundamental priorizar el aprendizaje continuo. La actualización constante de habilidades y conocimientos no solo mejora el desempeño profesional, sino que también abre puertas a nuevas oportunidades.
#
# ¿Cuál es la última habilidad o tecnología que has aprendido y cómo ha impactado en tu carrera? Comparte con nosotros y ayudemos a fomentar una comunidad de aprendizaje continuo.
#
# #AprendizajeContinuo #Tecnología"
# ----------------------------------------
#
# Análisis:
# • Palabras: 72 (límite: 150)
# • Hashtags: 2
# • Preguntas: 1
# • Cumple requisitos: ✓

# %%
# 3. EXTRACCIÓN DE INFORMACIÓN
def zero_shot_extraccion():
    print("=== ZERO-SHOT PARA EXTRACCIÓN ===")
    
    # Texto de ejemplo
    texto_noticia = """Apple Inc. anunció hoy que su CEO Tim Cook se reunirá con inversores 
    el próximo 15 de marzo de 2024 en Cupertino, California. La reunión abordará los 
    resultados financieros del Q1 2024, donde la compañía reportó ingresos de $89.5 
    billones. Cook también discutirá la nueva estrategia de IA de Apple y el lanzamiento 
    del iPhone 16 programado para septiembre. Las acciones de Apple (AAPL) subieron 
    3.2% tras el anuncio."""
    
    # Prompt para extracción estructurada
    extraccion_prompt = f"""Eres un analista financiero experto en extraer datos clave.
    
Extrae la siguiente información del texto dado:
    
Formato de respuesta (JSON):
{{
  "empresa": "nombre de la empresa",
  "ceo": "nombre del CEO",
  "fecha_evento": "fecha del evento",
  "ubicacion": "ubicación del evento",
  "ingresos": "cifra de ingresos mencionada",
  "productos": ["lista de productos mencionados"],
  "cambio_acciones": "porcentaje de cambio en acciones"
}}
    
Texto: "{texto_noticia}"
    
JSON:"""
    
    try:
        response = llm.invoke([HumanMessage(content=extraccion_prompt)])
        print("Información extraída:")
        print(response.content)
        
        # Intentar parsear como JSON para validar formato
        import json
        try:
            raw = response.content.strip()
            match = re.search(r'```(?:json)?\s*([\s\S]*?)\s*```', raw)
            cleaned = match.group(1) if match else raw
            data = json.loads(cleaned)
            print("\n✓ Formato JSON válido")
            print(f"✓ Campos extraídos: {len(data)} elementos")
        except:
            print("\n✗ Formato JSON inválido - necesita refinamiento del prompt")
            
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar extracción
zero_shot_extraccion()
# Out:
# === ZERO-SHOT PARA EXTRACCIÓN ===
# Información extraída:
# Aquí está la información extraída en formato JSON:
#
# ```
# {
#   "empresa": "Apple Inc.",
#   "ceo": "Tim Cook",
#   "fecha_evento": "15 de marzo de 2024",
#   "ubicacion": "Cupertino, California",
#   "ingresos": "$89.5 billones",
#   "productos": ["iPhone 16"],
#   "cambio_acciones": "3.2%"
# }
# ```
#
# ✓ Formato JSON válido
# ✓ Campos extraídos: 7 elementos

# %% [markdown]
# ## Optimización de Prompts Zero-Shot
#
# Técnicas para mejorar la efectividad de prompts zero-shot.

# %%
# Técnica 1: Prompts con Roles Específicos
def roles_especificos():
    print("=== OPTIMIZACIÓN: ROLES ESPECÍFICOS ===")
    
    pregunta = "¿Cómo puedo mejorar el rendimiento de mi aplicación web?"
    
    roles = {
        "Genérico": "Responde la siguiente pregunta:",
        "Desarrollador Senior": "Eres un desarrollador senior con 10 años de experiencia en optimización web. Responde como un experto:",
        "Consultor de Performance": "Eres un consultor especializado en performance web que ha optimizado cientos de aplicaciones. Proporciona una respuesta detallada y técnica:",
        "CTO": "Eres un CTO de una startup tecnológica. Responde con una perspectiva estratégica y técnica balanceada:"
    }
    
    for rol, contexto in roles.items():
        prompt = f"{contexto}\n\n{pregunta}"
        
        print(f"\n{rol.upper()}:")
        print("-" * 30)
        
        try:
            response = llm.invoke([HumanMessage(content=prompt)])
            # Mostrar solo las primeras líneas para comparación
            preview = response.content[:200] + "..." if len(response.content) > 200 else response.content
            print(preview)
        except Exception as e:
            print(f"Error: {e}")
    
    print("\n=== OBSERVACIONES ===")
    print("• Roles específicos generan respuestas más enfocadas")
    print("• La experticia del rol influye en la profundidad técnica")
    print("• El contexto profesional afecta el tipo de soluciones propuestas")

# Ejecutar ejemplo de roles
roles_especificos()
# Out:
# === OPTIMIZACIÓN: ROLES ESPECÍFICOS ===
#
# GENÉRICO:
# ------------------------------
# Existen varias formas de mejorar el rendimiento de una aplicación web, aquí te presento algunas sugerencias:
#
# 1. **Optimiza el código**: Asegúrate de que el código de tu aplicación sea eficiente y no ...
#
# DESARROLLADOR SENIOR:
# ------------------------------
# Excelente pregunta! La optimización del rendimiento de una aplicación web es un tema crucial para asegurar una experiencia de usuario fluida y satisfactoria. Con 10 años de experiencia en este campo, ...
#
# CONSULTOR DE PERFORMANCE:
# ------------------------------
# **Mejorar el Rendimiento de la Aplicación Web: Un Enfoque Integral**
#
# La optimización del rendimiento de una aplicación web es un proceso multifacético que requiere un enfoque integral para garantizar...
#
# CTO:
# ------------------------------
# Excelente pregunta! Como CTO de una startup tecnológica, puedo decir que mejorar el rendimiento de una aplicación web es un objetivo continuo que requiere una estrategia combinada de optimización técn...
#
# === OBSERVACIONES ===
# • Roles específicos generan respuestas más enfocadas
# • La experticia del rol influye en la profundidad técnica
# • El contexto profesional afecta el tipo de soluciones propuestas

# %%
# Técnica 2: Instrucciones Graduales
def instrucciones_graduales():
    print("=== OPTIMIZACIÓN: INSTRUCCIONES GRADUALES ===")
    
    # Problema complejo para demostrar
    problema = "Necesito crear una estrategia de marketing digital para lanzar una nueva app de fitness"
    
    # Prompt con instrucciones graduales
    prompt_gradual = f"""Eres un estratega de marketing digital senior.
    
Problema: {problema}
    
Desarrolla una estrategia siguiendo este proceso paso a paso:
    
PASO 1: Análisis inicial
- Identifica el público objetivo
- Define 3 puntos de valor únicos de la app
    
PASO 2: Canales de marketing
- Selecciona 4-5 canales digitales más efectivos
- Justifica cada selección
    
PASO 3: Estrategia de contenido
- Define tipos de contenido para cada canal
- Sugiere frecuencia de publicación
    
PASO 4: Métricas y KPIs
- Define 5 métricas clave para medir éxito
- Sugiere herramientas de medición
    
Desarrolla cada paso con detalle:"""
    
    try:
        response = llm.invoke([HumanMessage(content=prompt_gradual)])
        print("ESTRATEGIA DESARROLLADA:")
        print("=" * 50)
        print(response.content)
        
        # Análisis de estructura
        pasos_detectados = response.content.count("PASO")
        secciones = ["análisis", "canales", "contenido", "métricas"]
        secciones_encontradas = sum(1 for seccion in secciones if seccion.lower() in response.content.lower())
        
        print("\n=== ANÁLISIS DE ESTRUCTURA ===")
        print(f"• Pasos identificados: {pasos_detectados}/4")
        print(f"• Secciones cubiertas: {secciones_encontradas}/4")
        print(f"• Estructura seguida: {'✓' if pasos_detectados >= 3 else '✗'}")
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar instrucciones graduales
instrucciones_graduales()
# Out:
# === OPTIMIZACIÓN: INSTRUCCIONES GRADUALES ===
# ESTRATEGIA DESARROLLADA:
# ==================================================
# **PASO 1: Análisis inicial**
#
# Para crear una estrategia de marketing digital efectiva para la nueva app de fitness, es fundamental comenzar con un análisis inicial que nos permita entender a nuestro público objetivo y definir los puntos de valor únicos de la app.
#
# *   **Identifica el público objetivo:** El público objetivo para la app de fitness son personas que buscan mejorar su condición física, aumentar su bienestar y adoptar un estilo de vida saludable. Dentro de este grupo, se pueden identificar varios subgrupos, como:
#     *   Jóvenes adultos (18-35 años) que buscan mantenerse en forma y saludables.
#     *   Personas con objetivos de pérdida de peso o aumentar la masa muscular.
#     *   Atletas o deportistas que buscan mejorar su rendimiento.
#     *   Personas con condiciones de salud que requieren un programa de ejercicios personalizado.
# *   **Define 3 puntos de valor únicos de la app:** Los puntos de valor únicos de la app de fitness son:
#     1.  **Personalización:** La app ofrece programas de entrenamiento personalizados según las metas, el nivel de condición física y las preferencias del usuario.
#     2.  **Comunidad:** La app cuenta con una comunidad activa donde los usuarios pueden conectarse, compartir sus progresos, y recibir apoyo y motivación.
#     3.  **Tecnología de seguimiento avanzada:** La app utiliza tecnología de seguimiento avanzada para monitorear el progreso del usuario, proporcionar retroalimentación y ajustar los programas de entrenamiento según sea necesario.
#
# **PASO 2: Canales de marketing**
#
# Una vez que hemos identificado nuestro público objetivo y definido los puntos de valor únicos de la app, es hora de seleccionar los canales de marketing digitales más efectivos para alcanzar y engagear a nuestro público.
#
# *   **Selecciona 4-5 canales digitales más efectivos:** Los canales de marketing digitales que se han seleccionado para la app de fitness son:
#     1.  **Instagram:** Una plataforma visual ideal para compartir contenido de fitness, como rutinas de ejercicios, consejos de nutrición y progresos de los usuarios.
#     2.  **Facebook:** Un canal para compartir contenido más detallado, como artículos de blog, videos y anuncios dirigidos a nuestro público objetivo.
#     3.  **YouTube:** Un canal para crear contenido de video de alta calidad, como tutoriales de ejercicios, reviews de productos de fitness y entrevistas con expertos en el campo.
#     4.  **Twitter:** Un canal para compartir contenido breve y conciso, como consejos de fitness, noticias de la industria y promociones especiales.
#     5.  **Influencers de fitness:** Colaborar con influencers de fitness para promocionar la app y llegar a audiencias más amplias.
# *   **Justifica cada selección:** Cada canal ha sido seleccionado según su efectividad para alcanzar y engagear a nuestro público objetivo. Instagram y YouTube son ideales para contenido visual, mientras que Facebook y Twitter son mejores para contenido más detallado y conciso. La colaboración con influencers de fitness nos permite llegar a audiencias más amplias y creíbles en el nicho de fitness.
#
# **PASO 3: Estrategia de contenido**
#
# Con los canales de marketing seleccionados, es hora de definir la estrategia de contenido para cada canal.
#
# *   **Define tipos de contenido para cada canal:**
#     *   Instagram: Imágenes y videos de rutinas de ejercicios, consejos de nutrición, progresos de los usuarios y promociones especiales.
#     *   Facebook: Artículos de blog, videos, anuncios dirigidos y contenido de comunidad.
#     *   YouTube: Tutoriales de ejercicios, reviews de productos de fitness, entrevistas con expertos y contenido de estilo de vida saludable.
#     *   Twitter: Consejos de fitness, noticias de la industria, promociones especiales y contenido de comunidad.
#     *   Influencers de fitness: Contenido patrocinado, como reviews de la app, tutoriales de ejercicios y promociones especiales.
# *   **Sugiere frecuencia de publicación:**
#     *   Instagram: 3-4 publicaciones por semana.
#     *   Facebook: 2-3 publicaciones por semana.
#     *   YouTube: 1-2 videos por semana.
#     *   Twitter: 5-7 tweets por semana.
#     *   Influencers de fitness: 1-2 publicaciones por mes.
#
# **PASO 4: Métricas y KPIs**
#
# Para medir el éxito de nuestra estrategia de marketing digital, es fundamental definir métricas y KPIs clave.
#
# *   **Define 5 métricas clave para medir éxito:**
#     1.  **Descargas de la app:** El número de descargas de la app en las tiendas de aplicaciones.
#     2.  **Retención de usuarios:** El porcentaje de usuarios que siguen utilizando la app después de un período determinado.
#     3.  **Engagement:** La interacción de los usuarios con la app, como el tiempo de sesión, el número de sesiones y la participación en la comunidad.
#     4.  **Conversión:** El número de usuarios que completan un objetivo específico, como registrarse para un programa de entrenamiento o comprar un producto de fitness.
#     5.  **Valor de vida del usuario (CLV):** El valor total que un usuario aporta a la app a lo largo de su ciclo de vida.
# *   **Sugiere herramientas de medición:** Para medir estas métricas, se pueden utilizar herramientas como:
#     *   Google Analytics para medir descargas, retención y engagement.
#     *   Mixpanel para medir conversión y CLV.
#     *   App Annie para medir descargas y retención en las tiendas de aplicaciones.
#     *   Hootsuite Insights para medir engagement en las redes sociales.
#
# Al seguir estos pasos y definir una estrategia de marketing digital sólida, podemos aumentar la visibilidad, el engagement y la conversión para la nueva app de fitness, alcanzando nuestros objetivos de negocio y ayudando a más personas a alcanzar sus metas de fitness.
#
# === ANÁLISIS DE ESTRUCTURA ===
# • Pasos identificados: 4/4
# • Secciones cubiertas: 4/4
# • Estructura seguida: ✓

# %% [markdown]
# ## Casos de Uso Avanzados
#
# Aplicaciones más sofisticadas de zero-shot prompting.

# %%
# Caso de uso: Análisis de código
def analisis_codigo_zero_shot():
    print("=== CASO DE USO: ANÁLISIS DE CÓDIGO ===")
    
    codigo_ejemplo = '''def process_user_data(users):
    result = []
    for user in users:
        if user["age"] > 18:
            result.append({
                "name": user["name"].upper(),
                "email": user["email"],
                "status": "adult"
            })
    return result'''
    
    prompt_analisis = f"""Eres un senior code reviewer con experiencia en Python.
    
Analiza el siguiente código y proporciona:
    
1. FUNCIONALIDAD:
   - ¿Qué hace este código?
   - ¿Cuál es su propósito?
    
2. PROBLEMAS POTENCIALES:
   - Errores de lógica
   - Vulnerabilidades de seguridad
   - Problemas de rendimiento
    
3. MEJORAS SUGERIDAS:
   - Optimizaciones de código
   - Mejores prácticas
   - Manejo de errores
    
4. PUNTUACIÓN DE CALIDAD: [1-10]
    
Código a analizar:
```python
{codigo_ejemplo}
```
    
Análisis:"""
    
    try:
        response = llm.invoke([HumanMessage(content=prompt_analisis)])
        print("ANÁLISIS DE CÓDIGO:")
        print("=" * 50)
        print(response.content)
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar análisis de código
analisis_codigo_zero_shot()
# Out:
# === CASO DE USO: ANÁLISIS DE CÓDIGO ===
# ANÁLISIS DE CÓDIGO:
# ==================================================
# **Análisis del código**
#
# ### 1. FUNCIONALIDAD
#
# *   **Qué hace este código:** El código procesa una lista de usuarios y devuelve una nueva lista con información filtrada y transformada. La función `process_user_data` itera sobre cada usuario en la lista `users`, verifica si la edad del usuario es mayor a 18 y, si es así, crea un nuevo diccionario con el nombre en mayúsculas, el correo electrónico y un estado ("adulto"). Estos diccionarios son agregados a la lista `result`, que se devuelve al final.
# *   **Cuál es su propósito:** El propósito de este código es filtrar y transformar datos de usuarios para obtener una lista de usuarios adultos con cierta información específica.
#
# ### 2. PROBLEMAS POTENCIALES
#
# *   **Errores de lógica:**
#     *   La función asume que cada usuario tiene las claves "age", "name" y "email". Si algún usuario no tiene alguna de estas claves, el código generará un `KeyError`.
#     *   La función no maneja el caso en el que la edad del usuario no sea un número. Si la edad es un string o un valor no numérico, la comparación `user["age"] > 18` puede no funcionar como se espera.
# *   **Vulnerabilidades de seguridad:**
#     *   No se identifican vulnerabilidades de seguridad directas en este código, ya que no interactúa con fuentes externas de datos o no realiza operaciones que puedan ser explotadas. Sin embargo, siempre es importante considerar las fuentes de los datos y cómo se procesan para evitar posibles ataques de inyección de datos.
# *   **Problemas de rendimiento:**
#     *   La función tiene una complejidad temporal de O(n), donde n es el número de usuarios, lo que es aceptable para la tarea que realiza. Sin embargo, si la lista de usuarios es extremadamente grande, podría ser beneficioso considerar el uso de estructuras de datos más eficientes o métodos de procesamiento en paralelo.
#
# ### 3. MEJORAS SUGERIDAS
#
# *   **Optimizaciones de código:**
#     *   Utilizar listas por comprensión puede hacer el código más conciso y potencialmente más rápido.
#     *   Agregar un manejo de excepciones para claves faltantes o tipos de datos incorrectos en los diccionarios de usuarios.
# *   **Mejores prácticas:**
#     *   Utilizar nombres de variables y funciones más descriptivos puede mejorar la legibilidad del código.
#     *   Considerar el uso de una clase o estructura de datos más formal para representar a los usuarios, especialmente si se van a agregar más propiedades o métodos en el futuro.
# *   **Manejo de errores:**
#     *   Implementar un manejo de errores explícito para manejar casos como claves faltantes en los diccionarios de usuarios o edades no numéricas.
#
# ### 4. PUNTUACIÓN DE CALIDAD
#
# Considerando la funcionalidad, claridad y potenciales problemas identificados, le daría una puntuación de calidad de **7** sobre 10. El código es relativamente simple y fácil de entender, pero carece de manejo de errores y consideraciones de seguridad explícitas, lo que podría ser problemático en un entorno de producción. Con algunas mejoras en el manejo de errores y la adopción de mejores prácticas, este código podría ser más robusto y escalable.
#
# **Código mejorado:**
#
# ```python
# def procesar_datos_de_usuario(users):
#     """
#     Procesa una lista de usuarios y devuelve una nueva lista con información filtrada y transformada.
#
#     :param users: Lista de diccionarios, cada uno representando un usuario con claves "age", "name" y "email".
#     :return: Lista de diccionarios con información de usuarios adultos.
#     """
#     try:
#         result = [
#             {
#                 "nombre": user["nombre"].upper(),
#                 "correo": user["correo"],
#                 "estado": "adulto"
#             }
#             for user in users
#             if isinstance(user["edad"], (int, float)) and user["edad"] > 18
#         ]
#         return result
#     except KeyError as e:
#         print(f"Error: La clave {e} es necesaria para cada usuario.")
#         return []
#     except Exception as e:
#         print(f"Ocurrió un error: {e}")
#         return []
#
# # Ejemplo de uso
# usuarios = [
#     {"edad": 25, "nombre": "Juan", "correo": "juan@example.com"},
#     {"edad": 17, "nombre": "Ana", "correo": "ana@example.com"},
#     {"edad": 30, "nombre": "Pedro", "correo": "pedro@example.com"}
# ]
#
# usuarios_procesados = procesar_datos_de_usuario(usuarios)
# print(usuarios_procesados)
# ```
#
# Este código mejorado incluye manejo de excepciones para claves faltantes y tipos de datos incorrectos, y utiliza listas por comprensión para una sintaxis más concisa. También incluye documentación para explicar el propósito y el uso de la función.

# %%
# Caso de uso: Generación de tests
def generacion_tests_zero_shot():
    print("=== CASO DE USO: GENERACIÓN DE TESTS ===")
    
    funcion_a_testear = '''def calculate_discount(price, discount_percent, user_type):
    """Calculate final price after discount.
    
    Args:
        price (float): Original price
        discount_percent (float): Discount percentage (0-100)
        user_type (str): 'premium' or 'regular'
        
    Returns:
        float: Final price after discount
    """
    if user_type == 'premium':
        discount_percent += 5  # Extra 5% for premium users
    
    discount_amount = price * (discount_percent / 100)
    return price - discount_amount'''
    
    prompt_tests = f"""Eres un QA engineer experto en testing de Python.
    
Genera tests unitarios completos para la siguiente función usando pytest.
    
Incluye tests para:
1. Casos normales (diferentes tipos de usuario y descuentos)
2. Casos edge (descuento 0%, 100%, valores negativos)
3. Casos de error (tipos incorrectos, valores inválidos)
4. Tests parametrizados cuando sea apropiado
    
Función a testear:
```python
{funcion_a_testear}
```
    
Genera código de test completo y ejecutable:"""
    
    try:
        response = llm.invoke([HumanMessage(content=prompt_tests)])
        print("TESTS GENERADOS:")
        print("=" * 50)
        print(response.content)
        
        # Análisis básico de los tests generados
        test_methods = response.content.count("def test_")
        assertions = response.content.count("assert")
        parametrize = response.content.count("@pytest.mark.parametrize")
        
        print("\n=== ANÁLISIS DE TESTS ===")
        print(f"• Métodos de test: {test_methods}")
        print(f"• Assertions: {assertions}")
        print(f"• Tests parametrizados: {parametrize}")
        print(f"• Cobertura estimada: {'Alta' if test_methods >= 5 else 'Media' if test_methods >= 3 else 'Baja'}")
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar generación de tests
generacion_tests_zero_shot()
# Out:
# === CASO DE USO: GENERACIÓN DE TESTS ===
# TESTS GENERADOS:
# ==================================================
# **Testing de la función `calculate_discount` con Pytest**
#
# ```python
# import pytest
# from your_module import calculate_discount  # Reemplaza 'your_module' con el nombre de tu módulo
#
# # Tests parametrizados para casos normales
# @pytest.mark.parametrize("price, discount_percent, user_type, expected", [
#     (100, 10, 'regular', 90),
#     (100, 10, 'premium', 85),
#     (50, 20, 'regular', 40),
#     (50, 20, 'premium', 35),
# ])
# def test_calculate_discount_normal_cases(price, discount_percent, user_type, expected):
#     """Testea la función con casos normales"""
#     assert calculate_discount(price, discount_percent, user_type) == expected
#
# # Tests para casos edge
# def test_calculate_discount_zero_percent():
#     """Testea la función con descuento 0%"""
#     price = 100
#     discount_percent = 0
#     user_type = 'regular'
#     assert calculate_discount(price, discount_percent, user_type) == price
#
# def test_calculate_discount_hundred_percent():
#     """Testea la función con descuento 100%"""
#     price = 100
#     discount_percent = 100
#     user_type = 'regular'
#     assert calculate_discount(price, discount_percent, user_type) == 0
#
# def test_calculate_discount_negative_percent():
#     """Testea la función con descuento negativo"""
#     price = 100
#     discount_percent = -10
#     user_type = 'regular'
#     with pytest.raises(ValueError):
#         calculate_discount(price, discount_percent, user_type)
#
# # Tests para casos de error
# def test_calculate_discount_invalid_user_type():
#     """Testea la función con tipo de usuario inválido"""
#     price = 100
#     discount_percent = 10
#     user_type = 'invalid'
#     with pytest.raises(ValueError):
#         calculate_discount(price, discount_percent, user_type)
#
# def test_calculate_discount_invalid_price():
#     """Testea la función con precio inválido"""
#     price = -100
#     discount_percent = 10
#     user_type = 'regular'
#     with pytest.raises(ValueError):
#         calculate_discount(price, discount_percent, user_type)
#
# def test_calculate_discount_invalid_discount_percent():
#     """Testea la función con porcentaje de descuento inválido"""
#     price = 100
#     discount_percent = 110
#     user_type = 'regular'
#     with pytest.raises(ValueError):
#         calculate_discount(price, discount_percent, user_type)
#
# # Tests para tipos incorrectos
# def test_calculate_discount_invalid_price_type():
#     """Testea la función con tipo de precio inválido"""
#     price = '100'
#     discount_percent = 10
#     user_type = 'regular'
#     with pytest.raises(TypeError):
#         calculate_discount(price, discount_percent, user_type)
#
# def test_calculate_discount_invalid_discount_percent_type():
#     """Testea la función con tipo de porcentaje de descuento inválido"""
#     price = 100
#     discount_percent = '10'
#     user_type = 'regular'
#     with pytest.raises(TypeError):
#         calculate_discount(price, discount_percent, user_type)
#
# def test_calculate_discount_invalid_user_type_type():
#     """Testea la función con tipo de usuario inválido"""
#     price = 100
#     discount_percent = 10
#     user_type = 10
#     with pytest.raises(TypeError):
#         calculate_discount(price, discount_percent, user_type)
#
# # Necesitamos modificar la función original para que maneje los casos de error
# def calculate_discount(price, discount_percent, user_type):
#     """Calculate final price after discount.
#
#     Args:
#         price (float): Original price
#         discount_percent (float): Discount percentage (0-100)
#         user_type (str): 'premium' or 'regular'
#
#     Returns:
#         float: Final price after discount
#     """
#     if not isinstance(price, (int, float)) or price < 0:
#         raise ValueError("Precio inválido")
#     if not isinstance(discount_percent, (int, float)) or discount_percent < 0 or discount_percent > 100:
#         raise ValueError("Porcentaje de descuento inválido")
#     if not isinstance(user_type, str) or user_type not in ['premium', 'regular']:
#         raise ValueError("Tipo de usuario inválido")
#
#     if user_type == 'premium':
#         discount_percent += 5  # Extra 5% for premium users
#
#     discount_amount = price * (discount_percent / 100)
#     return price - discount_amount
# ```
#
# **Ejecución de los tests**
#
# Para ejecutar los tests, simplemente puedes ejecutar el comando `pytest` en la terminal, dentro del directorio donde se encuentra el archivo de tests. Si todos los tests pasan, no deberías ver ningún mensaje de error. Si algún test falla, se mostrará un mensaje de error con la información del test que falló y la razón por la que falló.
#
# === ANÁLISIS DE TESTS ===
# • Métodos de test: 10
# • Assertions: 3
# • Tests parametrizados: 1
# • Cobertura estimada: Alta

# %% [markdown]
# ## Mejores Prácticas y Limitaciones
#
# ### ✅ Cuándo Usar Zero-Shot:
# - Tareas comunes y bien definidas
# - Cuando no tienes ejemplos disponibles
# - Para prototipado rápido
# - Tareas que requieren creatividad
#
# ### ❌ Cuándo NO Usar Zero-Shot:
# - Formatos de salida muy específicos
# - Tareas de dominio muy especializado
# - Cuando la consistencia es crítica
# - Tareas complejas que requieren patrones específicos
#
# ### 🎯 Mejores Prácticas:
# 1. **Sé específico**: Detalla exactamente qué quieres
# 2. **Define el formato**: Especifica cómo debe verse la salida
# 3. **Establece restricciones**: Qué debe evitar o considerar
# 4. **Usa roles**: Define quién debe "ser" el modelo
# 5. **Itera y refina**: Mejora basándote en resultados

# %%
# Ejercicio final: Diseña tu propio prompt zero-shot
def ejercicio_personalizado():
    print("=== EJERCICIO PERSONAL ===")
    print("\nDiseña un prompt zero-shot para esta tarea:")
    print("'Crear una descripción de trabajo atractiva para un puesto de desarrollador Python junior'")
    print("\nEstructura sugerida:")
    print("1. Rol/Contexto del modelo")
    print("2. Tarea específica")
    print("3. Requisitos del formato")
    print("4. Restricciones importantes")
    print("\nTu prompt aquí:")
    
    # Espacio para que el estudiante diseñe su prompt
    prompt_estudiante = """# COLOCA TU PROMPT AQUÍ
    
# Ejemplo de estructura:
# Eres un [ROL]...
# Tarea: [TAREA ESPECÍFICA]...
# Formato: [ESTRUCTURA DE SALIDA]...
# Restricciones: [LIMITACIONES]...
"""
    
    print(prompt_estudiante)
    
    # Prompt de ejemplo bien estructurado
    ejemplo_prompt = """Eres un HR Business Partner senior especializado en tecnología con 8 años de experiencia reclutando desarrolladores.
    
Tarea: Redacta una descripción de trabajo atractiva y realista para un puesto de Desarrollador Python Junior.
    
Formato requerido:
- Título del puesto
- Resumen ejecutivo (2-3 líneas)
- Responsabilidades principales (4-5 puntos)
- Requisitos técnicos (separar esenciales de deseables)
- Beneficios y cultura de empresa
- Llamada a la acción
    
Restricciones:
- Máximo 400 palabras
- Lenguaje inclusivo y accesible
- Enfócate en crecimiento profesional
- Evita jerga técnica excesiva
- Sé honesto sobre el nivel junior
    
Descripción de trabajo:"""
    
    print("\n=== EJEMPLO DE PROMPT BIEN ESTRUCTURADO ===")
    print(ejemplo_prompt)
    
    # Opcional: probar el prompt ejemplo
    print("\n¿Quieres ver el resultado del prompt ejemplo? (y/n)")
    # En un entorno real, aquí habría input del usuario
    
ejercicio_personalizado()
# Out:
# === EJERCICIO PERSONAL ===
#
# Diseña un prompt zero-shot para esta tarea:
# 'Crear una descripción de trabajo atractiva para un puesto de desarrollador Python junior'
#
# Estructura sugerida:
# 1. Rol/Contexto del modelo
# 2. Tarea específica
# 3. Requisitos del formato
# 4. Restricciones importantes
#
# Tu prompt aquí:
# # COLOCA TU PROMPT AQUÍ
#
# # Ejemplo de estructura:
# # Eres un [ROL]...
# # Tarea: [TAREA ESPECÍFICA]...
# # Formato: [ESTRUCTURA DE SALIDA]...
# # Restricciones: [LIMITACIONES]...
#
#
# === EJEMPLO DE PROMPT BIEN ESTRUCTURADO ===
# Eres un HR Business Partner senior especializado en tecnología con 8 años de experiencia reclutando desarrolladores.
#
# Tarea: Redacta una descripción de trabajo atractiva y realista para un puesto de Desarrollador Python Junior.
#
# Formato requerido:
# - Título del puesto
# - Resumen ejecutivo (2-3 líneas)
# - Responsabilidades principales (4-5 puntos)
# - Requisitos técnicos (separar esenciales de deseables)
# - Beneficios y cultura de empresa
# - Llamada a la acción
#
# Restricciones:
# - Máximo 400 palabras
# - Lenguaje inclusivo y accesible
# - Enfócate en crecimiento profesional
# - Evita jerga técnica excesiva
# - Sé honesto sobre el nivel junior
#
# Descripción de trabajo:
#
# ¿Quieres ver el resultado del prompt ejemplo? (y/n)

# %% [markdown]
# ## Conceptos Clave Aprendidos
#
# 1. **Zero-shot prompting** es efectivo para tareas comunes sin necesidad de ejemplos
# 2. **Estructura clara** del prompt mejora significativamente los resultados
# 3. **Roles específicos** generan respuestas más enfocadas y expertas
# 4. **Instrucciones graduales** ayudan con tareas complejas
# 5. **Formato definido** asegura salidas consistentes y útiles
#
# ## Próximos Pasos
#
# En el siguiente notebook exploraremos **Few-Shot Prompting**, donde aprenderemos a usar ejemplos específicos para guiar el comportamiento del modelo y lograr mayor consistencia en tareas especializadas.
#
# ### Para Practicar:
# 1. Diseña prompts zero-shot para diferentes tipos de tareas
# 2. Experimenta con diferentes roles y contextos
# 3. Compara resultados con y sin estructura específica
# 4. Mide la consistencia en múltiples ejecuciones
