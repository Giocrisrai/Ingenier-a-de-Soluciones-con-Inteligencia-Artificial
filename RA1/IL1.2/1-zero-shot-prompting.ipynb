# %% [markdown]
# # 1. Zero-Shot Prompting - Prompts Sin Ejemplos Previos
#
# ## Objetivos de Aprendizaje
# - Comprender los principios del zero-shot prompting
# - Diseñar prompts efectivos sin ejemplos previos
# - Aplicar técnicas de instrucción clara y contexto
# - Evaluar la efectividad de diferentes enfoques zero-shot
#
# ## ¿Qué es Zero-Shot Prompting?
#
# Zero-shot prompting es la técnica donde pedimos al modelo realizar una tarea **sin proporcionar ejemplos específicos** de cómo debe hacerla. El modelo debe basarse únicamente en:
# - Su entrenamiento previo
# - Las instrucciones que le damos
# - El contexto que proporcionamos
#
# ### Ventajas:
# - **Simplicidad**: No requiere crear ejemplos
# - **Flexibilidad**: Fácil de adaptar a nuevas tareas
# - **Eficiencia**: Menos tokens utilizados
# - **Generalización**: Funciona para tareas diversas
#
# ### Limitaciones:
# - **Inconsistencia**: Resultados pueden variar más
# - **Formato**: Menos control sobre la estructura de salida
# - **Tareas complejas**: Puede requerir instrucciones muy detalladas
# - **Dominio específico**: Menos efectivo en nichos especializados

# %%
# Configuración inicial
import os

# Carga de credenciales: funciona igual en Google Colab y en local (.env)
try:
    from google.colab import userdata  # type: ignore
    os.environ["GROQ_API_KEY"] = userdata.get("GROQ_API_KEY")
except ImportError:
    from dotenv import load_dotenv
    load_dotenv()

assert os.getenv("GROQ_API_KEY"), "Falta GROQ_API_KEY (Colab: Secrets · local: archivo .env)"

MODELO = os.getenv("GROQ_MODEL", "openai/gpt-oss-120b")

from langchain_groq import ChatGroq
from langchain_core.messages import HumanMessage, SystemMessage
import re
import time

# Configurar el modelo (ChatGroq lee GROQ_API_KEY del entorno automáticamente)
llm = ChatGroq(
    model=MODELO,
    #temperature=0.7  # Balance entre creatividad y consistencia,
        reasoning_effort="low"
    )

print("✓ Modelo configurado para zero-shot prompting")
# Out:
# ✓ Modelo configurado para zero-shot prompting

# %% [markdown]
# ## Anatomía de un Prompt Zero-Shot Efectivo
#
# Un prompt zero-shot efectivo tiene estos componentes:
#
# 1. **Contexto/Rol**: Quién debe "ser" el modelo
# 2. **Tarea**: Qué debe hacer específicamente
# 3. **Formato**: Cómo debe estructurar la respuesta
# 4. **Restricciones**: Qué debe evitar o considerar
# 5. **Input**: Los datos específicos a procesar

# %%
# Ejemplo básico vs mejorado
def comparar_prompts_basico():
    texto = "El nuevo iPhone tiene una batería increíble y la cámara es fantástica, pero el precio es muy alto."
    
    # Prompt básico (menos efectivo)
    prompt_basico = f"Analiza este texto: {texto}"
    
    # Prompt mejorado (más efectivo)
    prompt_mejorado = f"""Eres un analista de sentimientos experto. 
    
Tarea: Analiza el sentimiento del siguiente texto sobre un producto.
    
Formato de respuesta:
- Sentimiento general: [Positivo/Negativo/Neutral]
- Aspectos positivos: [lista]
- Aspectos negativos: [lista]
- Puntuación de confianza: [0-10]
    
Texto a analizar: "{texto}"""
    
    print("=== COMPARACIÓN DE PROMPTS ===")
    
    # Probar prompt básico
    print("\n1. PROMPT BÁSICO:")
    print(f"Prompt: {prompt_basico}")
    try:
        response1 = llm.invoke([HumanMessage(content=prompt_basico)])
        print(f"Respuesta: {response1.content}")
    except Exception as e:
        print(f"Error: {e}")
    
    print("\n" + "-"*60)
    
    # Probar prompt mejorado
    print("\n2. PROMPT MEJORADO:")
    print(f"Prompt: {prompt_mejorado[:100]}...")
    try:
        response2 = llm.invoke([HumanMessage(content=prompt_mejorado)])
        print(f"Respuesta: {response2.content}")
    except Exception as e:
        print(f"Error: {e}")
    
    print("\n=== ANÁLISIS ===")
    print("• Prompt básico: Ambiguo, respuesta poco estructurada")
    print("• Prompt mejorado: Específico, respuesta estructurada y útil")

# Ejecutar comparación
comparar_prompts_basico()
# Out:
# === COMPARACIÓN DE PROMPTS ===
#
# 1. PROMPT BÁSICO:
# Prompt: Analiza este texto: El nuevo iPhone tiene una batería increíble y la cámara es fantástica, pero el precio es muy alto.
# Respuesta: **Análisis del texto**
#
# > *“El nuevo iPhone tiene una batería increíble y la cámara es fantástica, pero el precio es muy alto.”*
#
# | Elemento | Comentario | Valoración |
# |----------|------------|------------|
# | **Batería** | Se describe como “increíble”, indicando una percepción muy positiva respecto a la autonomía y desempeño. | Positiva |
# | **Cámara** | Calificada como “fantástica”, lo que sugiere alta satisfacción con la calidad de imagen y funcionalidades fotográficas. | Positiva |
# | **Precio** | Se menciona que “es muy alto”, señalando una objeción o preocupación respecto al costo. | Negativa |
# | **Conjunción “pero”** | Introduce una contraposición: los puntos fuertes (batería y cámara) se ven opacados o equilibrados por el inconveniente del precio. | Indica conflicto/tensión |
#
# ### Sentimiento global
# - **Mixto**: El mensaje combina elogios fuertes (batería y cámara) con una crítica significativa (precio).
# - La palabra “pero” sugiere que, aunque el producto tiene cualidades sobresalientes, el alto precio podría ser un factor decisivo para el consumidor.
#
# ### Implicaciones para marketing / comunicación
# 1. **Enfatizar los atributos positivos**: Resaltar la duración de la batería y la calidad de la cámara en campañas publicitarias.
# 2. **Justificar el precio**: Proveer argumentos que expliquen el valor añadido (tecnología premium, materiales, ecosistema, soporte, etc.) para mitigar la objeción del costo.
# 3. **Segmentación**: Dirigirse a usuarios dispuestos a pagar más por prestaciones superiores (fotógrafos aficionados, usuarios intensivos de móvil) y a aquellos que priorizan la relación calidad‑precio.
#
# ### Recomendación de respuesta al cliente
# - **Reconocer** la percepción positiva: “Nos alegra que la batería y la cámara cumplan con tus expectativas.”
# - **Abordar la preocupación**: “Entendemos que el precio es un factor importante; por eso ofrecemos planes de financiación y promociones especiales que hacen más accesible el dispositivo sin sacrificar sus prestaciones premium.”
#
# ------------------------------------------------------------
#
# 2. PROMPT MEJORADO:
# Prompt: Eres un analista de sentimientos experto.
#
# Tarea: Analiza el sentimiento del siguiente texto sobre ...
# Respuesta: - Sentimiento general: Positivo
# - Aspectos positivos:
#   1. Batería increíble
#   2. Cámara fantástica
# - Aspectos negativos:
#   1. Precio muy alto
# - Puntuación de confianza: 9
#
# === ANÁLISIS ===
# • Prompt básico: Ambiguo, respuesta poco estructurada
# • Prompt mejorado: Específico, respuesta estructurada y útil

# %% [markdown]
# ## Técnicas de Zero-Shot por Tipo de Tarea
#
# Diferentes tipos de tareas requieren enfoques específicos en zero-shot prompting.

# %%
# 1. CLASIFICACIÓN
def zero_shot_clasificacion():
    print("=== ZERO-SHOT PARA CLASIFICACIÓN ===")
    
    emails = [
        "Reunión de equipo mañana a las 10 AM en sala de conferencias",
        "¡Felicidades! Has ganado $1,000,000! Haz clic aquí ahora",
        "Recordatorio: Tu factura de internet vence en 3 días"
    ]
    
    # Prompt optimizado para clasificación
    clasificacion_prompt = """Eres un clasificador de emails empresariales.
    
Clasifica cada email en una de estas categorías:
- TRABAJO: Relacionado con tareas laborales
- SPAM: Contenido no solicitado o sospechoso
- PERSONAL: Asuntos personales o administrativos

Responde solo con el nombre de la categoría.

Email: "{}"
Categoría:"""
    
    for i, email in enumerate(emails, 1):
        prompt = clasificacion_prompt.format(email)
        try:
            response = llm.invoke([HumanMessage(content=prompt)])
            print(f"{i}. Email: {email[:50]}...")
            print(f"   Clasificación: {response.content.strip()}\n")
        except Exception as e:
            print(f"Error en email {i}: {e}")

# Ejecutar clasificación
zero_shot_clasificacion()
# Out:
# === ZERO-SHOT PARA CLASIFICACIÓN ===
# 1. Email: Reunión de equipo mañana a las 10 AM en sala de co...
#    Clasificación: TRABAJO
#
# 2. Email: ¡Felicidades! Has ganado $1,000,000! Haz clic aquí...
#    Clasificación: SPAM
#
# 3. Email: Recordatorio: Tu factura de internet vence en 3 dí...
#    Clasificación: PERSONAL

# %%
# 2. GENERACIÓN DE CONTENIDO
def zero_shot_generacion():
    print("=== ZERO-SHOT PARA GENERACIÓN ===")
    
    # Prompt estructurado para generación
    generacion_prompt = """Eres un copywriter creativo especializado en redes sociales.
    
Tarea: Crear un post para LinkedIn sobre el tema dado.
    
Requisitos:
- Tono profesional pero accesible
- Máximo 150 palabras
- Incluir 1-2 hashtags relevantes
- Hacer una pregunta para fomentar engagement
    
Tema: "Importancia del aprendizaje continuo en tecnología"
    
Post para LinkedIn:"""
    
    try:
        response = llm.invoke([HumanMessage(content=generacion_prompt)])
        print("Post generado:")
        print("-" * 40)
        print(response.content)
        print("-" * 40)
        
        # Análisis del resultado
        words = len(response.content.split())
        hashtags = response.content.count('#')
        questions = response.content.count('?')
        
        print(f"\nAnálisis:")
        print(f"• Palabras: {words} (límite: 150)")
        print(f"• Hashtags: {hashtags}")
        print(f"• Preguntas: {questions}")
        print(f"• Cumple requisitos: {'✓' if words <= 150 and hashtags >= 1 and questions >= 1 else '✗'}")
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar generación
zero_shot_generacion()
# Out:
# === ZERO-SHOT PARA GENERACIÓN ===
# Post generado:
# ----------------------------------------
# En un sector que avanza a la velocidad de la luz, el aprendizaje continuo no es opcional, es una necesidad estratégica. Cada nueva herramienta, lenguaje o marco abre puertas a soluciones más eficientes y a oportunidades de crecimiento profesional. Invertir tiempo en actualizar nuestras habilidades nos permite anticiparnos a los cambios, reducir la brecha de talento y aportar mayor valor a nuestros equipos y clientes.
#
# 💡 ¿Qué recurso o hábito has incorporado recientemente para mantenerte al día en tecnología?
#
# Comparte tu experiencia y enriquezcamos juntos la comunidad.
#
# #AprendizajeContinuo #TechLeadership
# ----------------------------------------
#
# Análisis:
# • Palabras: 89 (límite: 150)
# • Hashtags: 2
# • Preguntas: 1
# • Cumple requisitos: ✓

# %%
# 3. EXTRACCIÓN DE INFORMACIÓN
def zero_shot_extraccion():
    print("=== ZERO-SHOT PARA EXTRACCIÓN ===")
    
    # Texto de ejemplo
    texto_noticia = """Apple Inc. anunció hoy que su CEO Tim Cook se reunirá con inversores 
    el próximo 15 de marzo de 2024 en Cupertino, California. La reunión abordará los 
    resultados financieros del Q1 2024, donde la compañía reportó ingresos de $89.5 
    billones. Cook también discutirá la nueva estrategia de IA de Apple y el lanzamiento 
    del iPhone 16 programado para septiembre. Las acciones de Apple (AAPL) subieron 
    3.2% tras el anuncio."""
    
    # Prompt para extracción estructurada
    extraccion_prompt = f"""Eres un analista financiero experto en extraer datos clave.
    
Extrae la siguiente información del texto dado:
    
Formato de respuesta (JSON):
{{
  "empresa": "nombre de la empresa",
  "ceo": "nombre del CEO",
  "fecha_evento": "fecha del evento",
  "ubicacion": "ubicación del evento",
  "ingresos": "cifra de ingresos mencionada",
  "productos": ["lista de productos mencionados"],
  "cambio_acciones": "porcentaje de cambio en acciones"
}}
    
Texto: "{texto_noticia}"
    
JSON:"""
    
    try:
        response = llm.invoke([HumanMessage(content=extraccion_prompt)])
        print("Información extraída:")
        print(response.content)
        
        # Intentar parsear como JSON para validar formato
        import json
        try:
            raw = response.content.strip()
            match = re.search(r'```(?:json)?\s*([\s\S]*?)\s*```', raw)
            cleaned = match.group(1) if match else raw
            data = json.loads(cleaned)
            print("\n✓ Formato JSON válido")
            print(f"✓ Campos extraídos: {len(data)} elementos")
        except:
            print("\n✗ Formato JSON inválido - necesita refinamiento del prompt")
            
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar extracción
zero_shot_extraccion()
# Out:
# === ZERO-SHOT PARA EXTRACCIÓN ===
# Información extraída:
# {
#   "empresa": "Apple Inc.",
#   "ceo": "Tim Cook",
#   "fecha_evento": "15 de marzo de 2024",
#   "ubicacion": "Cupertino, California",
#   "ingresos": "$89.5 billones",
#   "productos": ["iPhone 16"],
#   "cambio_acciones": "3.2%"
# }
#
# ✓ Formato JSON válido
# ✓ Campos extraídos: 7 elementos

# %% [markdown]
# ## Optimización de Prompts Zero-Shot
#
# Técnicas para mejorar la efectividad de prompts zero-shot.

# %%
# Técnica 1: Prompts con Roles Específicos
def roles_especificos():
    print("=== OPTIMIZACIÓN: ROLES ESPECÍFICOS ===")
    
    pregunta = "¿Cómo puedo mejorar el rendimiento de mi aplicación web?"
    
    roles = {
        "Genérico": "Responde la siguiente pregunta:",
        "Desarrollador Senior": "Eres un desarrollador senior con 10 años de experiencia en optimización web. Responde como un experto:",
        "Consultor de Performance": "Eres un consultor especializado en performance web que ha optimizado cientos de aplicaciones. Proporciona una respuesta detallada y técnica:",
        "CTO": "Eres un CTO de una startup tecnológica. Responde con una perspectiva estratégica y técnica balanceada:"
    }
    
    for rol, contexto in roles.items():
        prompt = f"{contexto}\n\n{pregunta}"
        
        print(f"\n{rol.upper()}:")
        print("-" * 30)
        
        try:
            response = llm.invoke([HumanMessage(content=prompt)])
            # Mostrar solo las primeras líneas para comparación
            preview = response.content[:200] + "..." if len(response.content) > 200 else response.content
            print(preview)
        except Exception as e:
            print(f"Error: {e}")
    
    print("\n=== OBSERVACIONES ===")
    print("• Roles específicos generan respuestas más enfocadas")
    print("• La experticia del rol influye en la profundidad técnica")
    print("• El contexto profesional afecta el tipo de soluciones propuestas")

# Ejecutar ejemplo de roles
roles_especificos()
# Out:
# === OPTIMIZACIÓN: ROLES ESPECÍFICOS ===
#
# GENÉRICO:
# ------------------------------
# ¡Claro! Mejorar el rendimiento de una aplicación web es clave para ofrecer una buena experiencia de usuario, reducir la tasa de rebote y mejorar el SEO. A continuación tienes un plan estructurado con ...
#
# DESARROLLADOR SENIOR:
# ------------------------------
# ### Mejora del rendimiento de tu aplicación web
# *(enfoque integral: front‑end, back‑end, infraestructura y proceso)*
#
# ---
#
# ## 1. Métricas y línea base
# Antes de tocar código, define **qué medir**...
#
# CONSULTOR DE PERFORMANCE:
# ------------------------------
# ## Optimización de rendimiento para aplicaciones web
# *(Guía paso‑a‑paso, con referencias a estándares y herramientas de 2024)*
#
# ---
#
# ## 1. Medir antes de actuar
#
# | Herramienta | Qué mide | Cómo ...
#
# CTO:
# ------------------------------
# ### Visión Estratégica
# 1. **Define Métricas y SLAs claros**
#    - **Tiempo de respuesta (TTFB, FCP, LCP)**, **throughput** y **errores** deben estar alineados con los objetivos de negocio (p.ej., <...
#
# === OBSERVACIONES ===
# • Roles específicos generan respuestas más enfocadas
# • La experticia del rol influye en la profundidad técnica
# • El contexto profesional afecta el tipo de soluciones propuestas

# %%
# Técnica 2: Instrucciones Graduales
def instrucciones_graduales():
    print("=== OPTIMIZACIÓN: INSTRUCCIONES GRADUALES ===")
    
    # Problema complejo para demostrar
    problema = "Necesito crear una estrategia de marketing digital para lanzar una nueva app de fitness"
    
    # Prompt con instrucciones graduales
    prompt_gradual = f"""Eres un estratega de marketing digital senior.
    
Problema: {problema}
    
Desarrolla una estrategia siguiendo este proceso paso a paso:
    
PASO 1: Análisis inicial
- Identifica el público objetivo
- Define 3 puntos de valor únicos de la app
    
PASO 2: Canales de marketing
- Selecciona 4-5 canales digitales más efectivos
- Justifica cada selección
    
PASO 3: Estrategia de contenido
- Define tipos de contenido para cada canal
- Sugiere frecuencia de publicación
    
PASO 4: Métricas y KPIs
- Define 5 métricas clave para medir éxito
- Sugiere herramientas de medición
    
Desarrolla cada paso con detalle:"""
    
    try:
        response = llm.invoke([HumanMessage(content=prompt_gradual)])
        print("ESTRATEGIA DESARROLLADA:")
        print("=" * 50)
        print(response.content)
        
        # Análisis de estructura
        pasos_detectados = response.content.count("PASO")
        secciones = ["análisis", "canales", "contenido", "métricas"]
        secciones_encontradas = sum(1 for seccion in secciones if seccion.lower() in response.content.lower())
        
        print("\n=== ANÁLISIS DE ESTRUCTURA ===")
        print(f"• Pasos identificados: {pasos_detectados}/4")
        print(f"• Secciones cubiertas: {secciones_encontradas}/4")
        print(f"• Estructura seguida: {'✓' if pasos_detectados >= 3 else '✗'}")
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar instrucciones graduales
instrucciones_graduales()
# Out:
# === OPTIMIZACIÓN: INSTRUCCIONES GRADUALES ===
# ESTRATEGIA DESARROLLADA:
# ==================================================
# ## Estrategia de Marketing Digital para el Lanzamiento de **FitPulse** (App de Fitness)
#
# > **Objetivo global:** Generar awareness, adquirir usuarios activos (instalaciones y registro) y crear una comunidad comprometida que convierta a los primeros usuarios en defensores de la marca durante los primeros 6 meses.
#
# > **Horizonte temporal:** 12 meses divididos en 3 fases (Pre‑lanzamiento, Lanzamiento & Growth).
#
# > **Presupuesto estimado:** US $150 k (puede ajustarse según recursos internos).
#
# ---
#
# ## PASO 1 – ANÁLISIS INICIAL
#
# ### 1.1 Público objetivo (buyer personas)
#
# | Persona | Demografía | Psicografía | Necesidades / Dolor | Hábitos digitales |
# |--------|------------|-------------|----------------------|-------------------|
# | **Ana, la “Fit‑Newbie”** | 22‑35 años, mujer, estudiante o profesional junior, vive en ciudades medianas‑grandes. | Quiere ponerse en forma, le gusta la moda fitness, sigue a influencers. | Falta de tiempo, necesita rutinas guiadas, miedo a lesionarse. | Instagram, TikTok, YouTube, podcasts de bienestar. |
# | **Carlos, el “Gym‑Regular”** | 28‑45 años, hombre, empleo estable, ingresos medios‑altos. | Entrena 3‑5 veces/semana, busca optimizar rendimiento, le interesan datos y retos. | Aburrimiento de la rutina, necesita seguimiento de progreso y planes personalizados. | Reddit fitness, podcasts de entrenamiento, newsletters, apps de tracking. |
# | **María, la “Mamá‑Fit”** | 30‑45 años, madre de 1‑3 hijos, tiempo limitado, ingresos medios. | Busca entrenamientos cortos, flexibles, que pueda hacer en casa. | Falta de motivación, necesidad de comunidad y apoyo. | Facebook Groups, Pinterest, Instagram Stories, apps de salud. |
# | **Javier, el “Tech‑Enthusiast”** | 18‑30 años, estudiante o freelancer, amante de gadgets y datos. | Le encanta gamificación, retos, integración con wearables. | Quiere métricas precisas y recompensas. | TikTok, Discord, Twitch, foros de tecnología, newsletters. |
#
# > **Target primario**: Ana y Carlos (35 % del mercado total).
# > **Target secundario**: María y Javier (65 % restante), pero con mensajes y canales adaptados.
#
# ### 1.2 3 Puntos de Valor Únicos (UVP)
#
# | UVP | Descripción | Beneficio concreto |
# |-----|-------------|--------------------|
# | **1️⃣ Entrenamientos “AI‑Adaptive”** | Algoritmo de IA que ajusta la intensidad, repeticiones y tiempo en tiempo real según datos del smartwatch y feedback del usuario. | Cada sesión está optimizada para progresar sin sobrecarga, reduciendo el riesgo de lesión y maximizando resultados. |
# | **2️⃣ “FitPulse Challenges” con recompensas reales** | Retos semanales/mensuales con ranking, medallas digitales y cupones de marcas deportivas (p.ej., ropa, suplementos). | Gamificación que impulsa la adherencia y convierte a usuarios en promotores de la app. |
# | **3️⃣ Comunidad “Coach‑Live”** | Sesiones en vivo con entrenadores certificados + chat grupal moderado, acceso a Q&A y planes de nutrición personalizados. | Sentimiento de pertenencia y soporte profesional sin coste extra (incluido en suscripción premium). |
#
# ---
#
# ## PASO 2 – CANALES DE MARKETING
#
# | Canal | Por qué es efectivo para FitPulse | Rol dentro del funnel |
# |-------|-----------------------------------|-----------------------|
# | **1️⃣ Instagram + Reels / Stories** | Audiencia visual, alta adopción entre 18‑35 años, permite mostrar rutinas rápidas, testimonios y “behind the scenes”. | **Awareness → Consideration** (branding, generación de leads mediante swipe‑up a landing). |
# | **2️⃣ TikTok** | Crecimiento explosivo, formato corto ideal para “micro‑workouts” y retos virales; algoritmo favorece contenido de fitness. | **Awareness → Acquisition** (videos de challenges, UGC, hashtag brand). |
# | **3️⃣ Influencer Marketing (Micro + Macro)** | Credibilidad y alcance segmentado; micro‑influencers (10‑50 k) generan mayor engagement y ROI. | **Consideration → Conversion** (códigos de descuento, pruebas gratuitas). |
# | **4️⃣ Google Search & YouTube Ads** | Intención alta (búsqueda de “app de entrenamiento”, “rutinas en casa”). YouTube permite tutoriales y reviews. | **Consideration → Conversion** (costo por clic controlado, remarketing). |
# | **5️⃣ Email & SMS (CRM)** | Canal de retención y upsell; permite nutrir leads con contenido educativo y notificaciones de retos. | **Conversion → Retention** (welcome series, re‑engagement, cross‑sell premium). |
#
# > **Canales excluidos:** Radio, TV, prensa escrita – bajo ROI para un producto digital de nicho y alto costo de producción.
#
# ---
#
# ## PASO 3 – ESTRATEGIA DE CONTENIDO
#
# ### 3.1 Tipo de contenido por canal
#
# | Canal | Tipo de contenido | Objetivo | Formato | CTA principal |
# |-------|-------------------|----------|--------|---------------|
# | **Instagram** | • Reel de 15‑30 s “Workout of the Day” <br>• Carrusel “5 tips para evitar lesiones” <br>• Stories con encuestas y swipe‑up a demo | Enganche + educación | Video vertical, imágenes estáticas, stickers interactivos | “Descarga la app” / “Prueba 7 días gratis” |
# | **TikTok** | • Trend Challenge “#FitPulse30Sec” <br>• Duetos con usuarios que completan retos <br>• “Behind the AI” (explicación corta del algoritmo) | Viralidad + prueba social | Video vertical, música trending | “Link en bio” |
# | **Influencers** | • Review en IGTV/YouTube <br>• Live Workout usando la app <br>• Código de descuento exclusivo | Credibilidad + conversión | Video largo, stories, posts patrocinados | “Usa el código X para 20 % off” |
# | **Google Search Ads** | • Texto persuasivo con USP (AI‑Adaptive, Challenges) <br>• Extensiones de llamada a la acción | Captura de intención | Texto + extensiones | “Descarga ahora” |
# | **YouTube Ads** | • 15 s pre‑roll “¿Quieres entrenar como un pro? Descubre FitPulse” <br>• 60 s “Historia de transformación” (testimonio) | Awareness + consideración | Video horizontal | “Instala la app” |
# | **Email / SMS** | • Welcome series (día 0, 2, 5) con tutoriales <br>• Newsletter semanal “Reto de la semana + tips” <br>• Reactivación “Te extrañamos, vuelve con 3 días gratis” | Nutrición + retención | Texto + GIFs, enlaces deep‑link | “Abrir app”, “Upgrade premium” |
#
# ### 3.2 Frecuencia recomendada
#
# | Canal | Publicaciones semanales | Comentario |
# |-------|------------------------|------------|
# | Instagram Feed/Reels | 4‑5 | Lunes (motivación), Miércoles (tip), Viernes (reto), Domingo (testimonio) |
# | Instagram Stories | 7‑10 (diario) | Encuestas, Q&A, recordatorio de retos |
# | TikTok | 3‑4 | Lunes, Jueves, Sábado + contenido generado por usuarios (UGC) |
# | Influencer colaboraciones | 2‑3 al mes (macro) + 5‑8 micro‑influencers continuos | Rotación para evitar saturación |
# | Google Search Ads | Continuo (presupuesto diario) | Ajustes CPC según rendimiento |
# | YouTube Ads | 2‑3 campañas mensuales (brand + performance) | Rotación de creatividades cada 2 semanas |
# | Email | 1‑2 por semana (según segmentación) | Segmentos: nuevos, activos, inactivos |
# | SMS | 1‑2 al mes (recordatorio de reto, oferta) | Sólo a usuarios que optaron por recibir SMS |
#
# ---
#
# ## PASO 4 – MÉTRICAS Y KPIs
#
# | KPI | Qué mide | Fórmula / Fuente | Meta 3 meses | Herramienta |
# |-----|----------|------------------|--------------|-------------|
# | **1️⃣ CAC (Costo de adquisición de cliente)** | Inversión total / número de usuarios pagados adquiridos. | Σ gasto marketing ÷ # usuarios premium | ≤ US $12 | Google Ads, Meta Ads Manager, Mixpanel |
# | **2️⃣ DAU / MAU (Usuarios activos diarios y mensuales)** | Retención y engagement. | # usuarios únicos que abren la app / periodo | DAU/MAU ≥ 30 % | Firebase Analytics |
# | **3️⃣ Tasa de conversión de instalación → registro** | Eficiencia del onboarding. | # registros ÷ # instalaciones *100 | ≥ 45 % | Adjust / Appsflyer |
# | **4️⃣ Retención a 7 días y 30 días** | Adhesión temprana. | # usuarios activos día 7 (o 30) ÷ # usuarios instalados día 0 *100 | 7‑días ≥ 35 %, 30‑días ≥ 20 % | Firebase, Amplitude |
# | **5️⃣ NPS (Net Promoter Score) de usuarios premium** | Satisfacción y potencial de boca‑a‑boca. | %Promotores – %Detractores (escala 0‑10) | ≥ 50 | SurveyMonkey / Typeform (en‑app) |
#
# ### Herramientas de medición recomendadas
#
# | Necesidad | Herramienta | Por qué |
# |-----------|------------|----------|
# | **Analítica de app** | **Firebase** (Analytics + Crashlytics + Remote Config) | Integración nativa, eventos personalizados, cohort analysis. |
# | **Atribución y CAC** | **Adjust** o **Appsflyer** | Seguimiento de fuentes de instalación, cálculo de LTV/CAC. |
# | **Gestión de campañas sociales** | **Meta Business Suite**, **TikTok Ads Manager** | Reporting consolidado, pruebas A/B. |
# | **Email & SMS** | **Klaviyo** (email) + **Twilio** (SMS) | Segmentación avanzada, automatizaciones basadas en comportamiento. |
# | **Dashboard ejecutivo** | **Google Data Studio** o **Tableau** (conectado a BigQuery) | Visualiza todos los KPIs en tiempo real para decisiones rápidas. |
# | **Encuestas NPS** | **Typeform** + integración a Firebase | Encuestas in‑app sin fricción. |
#
# ---
#
# ## RESUMEN DE IMPLEMENTACIÓN (12 meses)
#
# | Mes | Acción clave | Resultado esperado |
# |-----|--------------|--------------------|
# | **0‑1** | Investigación de mercado, definición de creatividades, set‑up de tracking. | Infraestructura de datos lista, UVP afinados. |
# | **2‑3** (Pre‑lanzamiento) | Teaser en Instagram/TikTok, campaña de “Waitlist” con incentivo (30 días gratis). | 20 k leads en lista, hype + email capture. |
# | **4** (Lanzamiento) | Evento live con influencers + giveaway, ads de performance, push de “challenge inaugural”. | 100 k descargas, 15 % registro, 5 % premium (early‑bird). |
# | **5‑6** | Optimización de creatividades (A/B), inicio de programa de referidos (2 % de usuarios referidos). | CAC ↓ 15 %, Retención 7‑días ↑ 10 %. |
# | **7‑9** | Expansión a podcasts y colaboraciones con marcas deportivas (cupones). | LTV ↑ 20 %, NPS ≥ 45. |
# | **10‑12** | Introducción de “Coach‑Live” premium, campaña de retención (email + SMS). | Conversión a premium ↑ 8 %, churn 30‑días ↓ 5 %. |
#
# ---
#
# ### 🎯 Próximos pasos inmediatos
#
# 1. **Crear el brief creativo** con los 3 UVP y los formatos de contenido para cada canal.
# 2. **Configurar el stack de medición** (Firebase + Adjust + Data Studio).
# 3. **Seleccionar 3 micro‑influencers** (fitness + lifestyle) y 1 macro‑influencer para el lanzamiento.
# 4. **Diseñar la landing page “Waitlist”** con lead magnet (e‑book “30 días de rutinas rápidas”).
# 5. **Planificar el calendario editorial** (hoja de cálculo compartida) para los primeros 8 semanas.
#
# Con este plan estructurado, FitPulse tendrá una base sólida para generar awareness, adquirir usuarios de calidad y crear una comunidad leal que impulse el crecimiento sostenible de la app. ¡Éxitos en el lanzamiento! 🚀
#
# === ANÁLISIS DE ESTRUCTURA ===
# • Pasos identificados: 4/4
# • Secciones cubiertas: 4/4
# • Estructura seguida: ✓

# %% [markdown]
# ## Casos de Uso Avanzados
#
# Aplicaciones más sofisticadas de zero-shot prompting.

# %%
# Caso de uso: Análisis de código
def analisis_codigo_zero_shot():
    print("=== CASO DE USO: ANÁLISIS DE CÓDIGO ===")
    
    codigo_ejemplo = '''def process_user_data(users):
    result = []
    for user in users:
        if user["age"] > 18:
            result.append({
                "name": user["name"].upper(),
                "email": user["email"],
                "status": "adult"
            })
    return result'''
    
    prompt_analisis = f"""Eres un senior code reviewer con experiencia en Python.
    
Analiza el siguiente código y proporciona:
    
1. FUNCIONALIDAD:
   - ¿Qué hace este código?
   - ¿Cuál es su propósito?
    
2. PROBLEMAS POTENCIALES:
   - Errores de lógica
   - Vulnerabilidades de seguridad
   - Problemas de rendimiento
    
3. MEJORAS SUGERIDAS:
   - Optimizaciones de código
   - Mejores prácticas
   - Manejo de errores
    
4. PUNTUACIÓN DE CALIDAD: [1-10]
    
Código a analizar:
```python
{codigo_ejemplo}
```
    
Análisis:"""
    
    try:
        response = llm.invoke([HumanMessage(content=prompt_analisis)])
        print("ANÁLISIS DE CÓDIGO:")
        print("=" * 50)
        print(response.content)
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar análisis de código
analisis_codigo_zero_shot()
# Out:
# === CASO DE USO: ANÁLISIS DE CÓDIGO ===
# ANÁLISIS DE CÓDIGO:
# ==================================================
# **1. FUNCIONALIDAD**
#
# | Pregunta | Respuesta |
# |----------|-----------|
# | **¿Qué hace este código?** | La función `process_user_data` recibe una lista de diccionarios (cada uno representa a un usuario) y devuelve una nueva lista con los usuarios cuya edad es mayor a 18 años. Para cada usuario adulto se crea un nuevo diccionario con: <br>• `name` en mayúsculas <br>• `email` tal cual <br>• `status` con el valor fijo `"adult"` |
# | **¿Cuál es su propósito?** | Filtrar usuarios menores de edad y normalizar (capitalizar) el nombre de los adultos, añadiendo un campo de estado. Es un paso típico en pipelines de procesamiento de datos antes de guardarlos o enviarlos a otro sistema. |
#
# ---
#
# **2. PROBLEMAS POTENCIALES**
#
# | Tipo | Problema | Detalle |
# |------|----------|---------|
# | **Lógica** | **Suposición de claves** | Se asume que cada `user` tiene las claves `"age"`, `"name"` y `"email"`. Si falta alguna, se lanzará `KeyError`. |
# | | **Condición estricta** | Sólo se incluyen usuarios **mayores** que 18. Si la intención fuera “mayores o iguales a 18”, la condición está equivocada. |
# | **Seguridad** | **Exposición de datos sensibles** | El `email` se devuelve sin ningún tipo de enmascaramiento o validación. En contextos donde el email es información sensible, podría ser un riesgo. |
# | | **Inyección de datos** | No hay sanitización de los valores de `name` o `email`. Si la salida se usa posteriormente en HTML/SQL sin escape, podría generar vulnerabilidades de XSS/SQLi. |
# | **Rendimiento** | **Iteración y creación de listas** | Para listas muy grandes (millones de usuarios) la construcción de una lista completa en memoria (`result`) puede consumir mucha RAM. |
# | | **Operación `upper()`** | `str.upper()` es O(n) sobre la longitud del nombre; no es crítico, pero si se procesa millones de registros podría sumar. |
# | **Otros** | **Tipado estático** | No hay anotaciones de tipos, lo que dificulta la detección temprana de errores y la autocompletación en IDEs. |
#
# ---
#
# **3. MEJORAS SUGERIDAS**
#
# | Área | Mejora | Código de ejemplo |
# |------|--------|--------------------|
# | **Validación y manejo de errores** | Utilizar `.get()` con valores por defecto o validar la estructura antes de procesar. | ```python\nif user.get("age") is None:\n    continue  # o registrar error\n``` |
# | | Lanzar una excepción clara si la estructura es incorrecta. | ```python\nrequired = {"age", "name", "email"}\nif not required.issubset(user):\n    raise ValueError(f"Missing keys in user: {required - user.keys()}")\n``` |
# | **Claridad de condición** | Decidir si se incluye 18 años. | ```python\nif user["age"] >= 18:  # si 18 se considera adulto\n``` |
# | **Tipado** | Añadir anotaciones de tipos para facilitar el mantenimiento. | ```python\nfrom typing import List, Dict, Any\n\ndef process_user_data(users: List[Dict[str, Any]]) -> List[Dict[str, str]]:\n    ...\n``` |
# | **Rendimiento / memoria** | Convertir la función en un generador para procesar datos en streaming. | ```python\ndef process_user_data(users):\n    for user in users:\n        if user.get(\"age\", 0) > 18:\n            yield {\n                \"name\": user[\"name\"].upper(),\n                \"email\": user[\"email\"],\n                \"status\": \"adult\",\n            }\n``` |
# | **Seguridad / saneamiento** | Escapar o validar campos antes de devolverlos (p.ej., usar `email.strip().lower()`). | ```python\nemail = user[\"email\"].strip().lower()\n``` |
# | **Documentación** | Añadir docstring explicando parámetros, retorno y posibles excepciones. | ```python\n\"\"\"Filtra usuarios adultos y normaliza sus datos.\n\nArgs:\n    users: iterable of dicts with keys 'name', 'email', 'age'.\n\nReturns:\n    List of dicts with normalized fields for adults.\n\"\"\"\n``` |
# | **Testing** | Escribir pruebas unitarias (pytest) que cubran casos: <br>• usuario sin edad <br>• edad = 18 <br>• nombre con caracteres especiales <br>• lista vacía | ```python\ndef test_process_user_data():\n    users = [{\"name\": \"Ana\", \"email\": \"a@b.com\", \"age\": 19}]\n    assert process_user_data(users) == [{\"name\": \"ANA\", \"email\": \"a@b.com\", \"status\": \"adult\"}]\n``` |
# | **Uso de `dataclass`** (opcional) | Si los usuarios son objetos bien definidos, usar `@dataclass` para mayor claridad. | ```python\nfrom dataclasses import dataclass\n\n@dataclass\nclass User:\n    name: str\n    email: str\n    age: int\n``` |
#
# ---
#
# **4. PUNTUACIÓN DE CALIDAD**
#
# | Criterio | Valor (1‑10) |
# |----------|--------------|
# | **Legibilidad** | 7 – código corto y claro, pero falta docstring y tipado. |
# | **Robustez** | 4 – asume claves presentes, no maneja errores, posible exposición de datos. |
# | **Rendimiento** | 6 – suficiente para listas pequeñas; no escala bien a gran volumen. |
# | **Seguridad** | 3 – no hay saneamiento ni protección de datos sensibles. |
# | **Mantenibilidad** | 5 – ausencia de pruebas, tipado y documentación limita el mantenimiento. |
#
# **Puntuación global:** **5/10**
#
# ---
#
# **Resumen rápido:**
# El algoritmo cumple su objetivo básico, pero necesita validación de entrada, manejo de errores, documentación, tipado y, preferiblemente, un enfoque basado en generadores o procesamiento por lotes para grandes volúmenes. Además, considerar la privacidad del email y sanitizar los campos antes de exponerlos. Con las mejoras sugeridas, la función será más segura, robusta y fácil de mantener.

# %%
# Caso de uso: Generación de tests
def generacion_tests_zero_shot():
    print("=== CASO DE USO: GENERACIÓN DE TESTS ===")
    
    funcion_a_testear = '''def calculate_discount(price, discount_percent, user_type):
    """Calculate final price after discount.
    
    Args:
        price (float): Original price
        discount_percent (float): Discount percentage (0-100)
        user_type (str): 'premium' or 'regular'
        
    Returns:
        float: Final price after discount
    """
    if user_type == 'premium':
        discount_percent += 5  # Extra 5% for premium users
    
    discount_amount = price * (discount_percent / 100)
    return price - discount_amount'''
    
    prompt_tests = f"""Eres un QA engineer experto en testing de Python.
    
Genera tests unitarios completos para la siguiente función usando pytest.
    
Incluye tests para:
1. Casos normales (diferentes tipos de usuario y descuentos)
2. Casos edge (descuento 0%, 100%, valores negativos)
3. Casos de error (tipos incorrectos, valores inválidos)
4. Tests parametrizados cuando sea apropiado
    
Función a testear:
```python
{funcion_a_testear}
```
    
Genera código de test completo y ejecutable:"""
    
    try:
        response = llm.invoke([HumanMessage(content=prompt_tests)])
        print("TESTS GENERADOS:")
        print("=" * 50)
        print(response.content)
        
        # Análisis básico de los tests generados
        test_methods = response.content.count("def test_")
        assertions = response.content.count("assert")
        parametrize = response.content.count("@pytest.mark.parametrize")
        
        print("\n=== ANÁLISIS DE TESTS ===")
        print(f"• Métodos de test: {test_methods}")
        print(f"• Assertions: {assertions}")
        print(f"• Tests parametrizados: {parametrize}")
        print(f"• Cobertura estimada: {'Alta' if test_methods >= 5 else 'Media' if test_methods >= 3 else 'Baja'}")
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar generación de tests
generacion_tests_zero_shot()
# Out:
# === CASO DE USO: GENERACIÓN DE TESTS ===
# TESTS GENERADOS:
# ==================================================
# **Archivo de tests**
# Guarda el siguiente contenido en `test_calculate_discount.py` al mismo nivel que el módulo que contiene `calculate_discount` (por ejemplo, `discount.py`).
#
# ```python
# # test_calculate_discount.py
# import pytest
#
# # Importamos la función a probar. Cambia el nombre del módulo si es necesario.
# # -------------------------------------------------
# # from discount import calculate_discount
# # -------------------------------------------------
# # Para que el ejemplo sea completamente autocontenido, definimos la función aquí.
# # En tu proyecto elimina esta definición y usa la importación anterior.
# def calculate_discount(price, discount_percent, user_type):
#     """Calculate final price after discount.
#
#     Args:
#         price (float): Original price
#         discount_percent (float): Discount percentage (0-100)
#         user_type (str): 'premium' or 'regular'
#
#     Returns:
#         float: Final price after discount
#     """
#     if user_type == 'premium':
#         discount_percent += 5  # Extra 5% for premium users
#
#     discount_amount = price * (discount_percent / 100)
#     return price - discount_amount
# # -------------------------------------------------
#
#
# # ----------------------------------------------------------------------
# # 1. CASOS NORMALES – diferentes tipos de usuario y descuentos
# # ----------------------------------------------------------------------
# @pytest.mark.parametrize(
#     "price, discount_percent, user_type, expected",
#     [
#         (100.0, 10, "regular", 90.0),          # 10% descuento regular
#         (200.0, 20, "regular", 160.0),         # 20% descuento regular
#         (150.0, 15, "premium", 127.5),         # 15% + 5% extra = 20% → 150*0.8 = 120
#         (80.0, 0, "premium", 76.0),            # 0% + 5% extra = 5% → 80*0.95 = 76
#         (50.0, 5, "premium", 45.0),            # 5% + 5% = 10% → 50*0.9 = 45
#         (120.0, 30, "regular", 84.0),          # 30% regular
#     ],
# )
# def test_calculate_discount_normal(price, discount_percent, user_type, expected):
#     """Prueba casos típicos de cálculo de descuento."""
#     result = calculate_discount(price, discount_percent, user_type)
#     assert result == pytest.approx(expected)
#
#
# # ----------------------------------------------------------------------
# # 2. CASOS EDGE – 0%, 100% y valores negativos
# # ----------------------------------------------------------------------
# @pytest.mark.parametrize(
#     "price, discount_percent, user_type, expected",
#     [
#         (100.0, 0, "regular", 100.0),          # sin descuento
#         (100.0, 0, "premium", 95.0),           # premium agrega +5%
#         (100.0, 100, "regular", 0.0),          # descuento total
#         (100.0, 95, "premium", 0.0),           # 95 + 5 = 100% → precio 0
#         (100.0, -10, "regular", 110.0),        # descuento negativo = aumento del 10%
#         (100.0, -5, "premium", 110.0),         # -5 +5 = 0% → precio sin cambio
#     ],
# )
# def test_calculate_discount_edge(price, discount_percent, user_type, expected):
#     """Prueba valores límite y comportamientos inesperados pero válidos."""
#     result = calculate_discount(price, discount_percent, user_type)
#     assert result == pytest.approx(expected)
#
#
# # ----------------------------------------------------------------------
# # 3. CASOS DE ERROR – tipos incorrectos / valores no numéricos
# # ----------------------------------------------------------------------
# @pytest.mark.parametrize(
#     "price, discount_percent, user_type, exc_type",
#     [
#         ("100", 10, "regular", TypeError),          # price no es numérico
#         (100, "10", "regular", TypeError),          # discount_percent no es numérico
#         (100, 10, 123, TypeError),                  # user_type no es str
#         (None, 10, "regular", TypeError),           # price es None
#         (100, None, "regular", TypeError),          # discount_percent es None
#         (100, 10, None, TypeError),                 # user_type es None
#     ],
# )
# def test_calculate_discount_type_errors(price, discount_percent, user_type, exc_type):
#     """Asegura que la función falle de forma predecible cuando los tipos son incorrectos."""
#     with pytest.raises(exc_type):
#         # La función original no valida tipos explícitamente, por lo que
#         # Python lanzará TypeError al intentar operar con tipos incompatibles.
#         calculate_discount(price, discount_percent, user_type)
#
#
# # ----------------------------------------------------------------------
# # 4. VALIDACIÓN ADICIONAL – comportamiento con valores no numéricos que
# #    sí pueden convertirse (ej. strings numéricos). Aquí demostramos que
# #    la función NO los acepta, por lo que esperamos TypeError.
# # ----------------------------------------------------------------------
# def test_calculate_discount_string_numbers_not_accepted():
#     """Comprobamos que strings numéricos no son convertidos implícitamente."""
#     with pytest.raises(TypeError):
#         calculate_discount("100.0", "20", "regular")
#
#
# # ----------------------------------------------------------------------
# # 5. PRUEBA DE PRECISIÓN – uso de `pytest.approx` con tolerancia
# # ----------------------------------------------------------------------
# def test_calculate_discount_precision():
#     """Comprueba que la precisión de punto flotante es manejada correctamente."""
#     price = 123.456
#     discount_percent = 12.34
#     expected = price - price * (discount_percent / 100)  # cálculo de referencia
#     result = calculate_discount(price, discount_percent, "regular")
#     assert result == pytest.approx(expected, rel=1e-9)
#
#
# # ----------------------------------------------------------------------
# # 6. PRUEBAS DE INTEGRIDAD DE ENTRADA – valores extremadamente grandes
# # ----------------------------------------------------------------------
# @pytest.mark.parametrize(
#     "price, discount_percent, user_type, expected",
#     [
#         (1e12, 50, "regular", 5e11),      # mitad del precio
#         (1e12, 45, "premium", 5e11),      # 45+5=50% → 5e11
#     ],
# )
# def test_calculate_discount_large_numbers(price, discount_percent, user_type, expected):
#     """Asegura que la función sigue funcionando con números muy grandes."""
#     result = calculate_discount(price, discount_percent, user_type)
#     assert result == pytest.approx(expected)
#
#
# # ----------------------------------------------------------------------
# # 7. PRUEBAS DE COMPORTAMIENTO DE USUARIO NO RECONOCIDO
# # ----------------------------------------------------------------------
# def test_calculate_discount_unknown_user_type():
#     """Si el user_type no es 'premium' ni 'regular' la función lo trata como regular."""
#     price = 100.0
#     discount_percent = 10
#     result = calculate_discount(price, discount_percent, "guest")
#     # No se añade el +5% extra
#     assert result == pytest.approx(90.0)
# ```
#
# ### Instrucciones para ejecutar los tests
# 1. **Instala pytest** (si aún no lo tienes):
#    ```bash
#    pip install pytest
#    ```
#
# 2. **Ejecuta los tests** desde la raíz del proyecto:
#    ```bash
#    pytest -q
#    ```
#
#    Verás una salida similar a:
#    ```
#    ..........
#    11 passed in 0.03s
#    ```
#
# ### Comentarios sobre la cobertura
# - **Casos normales**: combinaciones de precios, porcentajes y tipos de usuario.
# - **Edge cases**: 0 %, 100 %, descuentos negativos y el efecto del +5 % premium.
# - **Errores**: tipos de datos incorrectos, garantizando que se lance `TypeError`.
# - **Parametrización**: se usa `@pytest.mark.parametrize` para evitar código repetitivo y facilitar la lectura.
# - **Precisión**: se verifica con `pytest.approx` para evitar fallos por redondeo.
# - **Comportamiento inesperado**: se prueba que un `user_type` desconocido se trata como “regular”.
#
# Con este conjunto de pruebas tendrás una buena cobertura de la lógica de `calculate_discount` y detectarás tanto regresiones como usos indebidos de la API. ¡Éxitos!
#
# === ANÁLISIS DE TESTS ===
# • Métodos de test: 7
# • Assertions: 5
# • Tests parametrizados: 5
# • Cobertura estimada: Alta

# %% [markdown]
# ## Mejores Prácticas y Limitaciones
#
# ### ✅ Cuándo Usar Zero-Shot:
# - Tareas comunes y bien definidas
# - Cuando no tienes ejemplos disponibles
# - Para prototipado rápido
# - Tareas que requieren creatividad
#
# ### ❌ Cuándo NO Usar Zero-Shot:
# - Formatos de salida muy específicos
# - Tareas de dominio muy especializado
# - Cuando la consistencia es crítica
# - Tareas complejas que requieren patrones específicos
#
# ### 🎯 Mejores Prácticas:
# 1. **Sé específico**: Detalla exactamente qué quieres
# 2. **Define el formato**: Especifica cómo debe verse la salida
# 3. **Establece restricciones**: Qué debe evitar o considerar
# 4. **Usa roles**: Define quién debe "ser" el modelo
# 5. **Itera y refina**: Mejora basándote en resultados

# %%
# Ejercicio final: Diseña tu propio prompt zero-shot
def ejercicio_personalizado():
    print("=== EJERCICIO PERSONAL ===")
    print("\nDiseña un prompt zero-shot para esta tarea:")
    print("'Crear una descripción de trabajo atractiva para un puesto de desarrollador Python junior'")
    print("\nEstructura sugerida:")
    print("1. Rol/Contexto del modelo")
    print("2. Tarea específica")
    print("3. Requisitos del formato")
    print("4. Restricciones importantes")
    print("\nTu prompt aquí:")
    
    # Espacio para que el estudiante diseñe su prompt
    prompt_estudiante = """# COLOCA TU PROMPT AQUÍ
    
# Ejemplo de estructura:
# Eres un [ROL]...
# Tarea: [TAREA ESPECÍFICA]...
# Formato: [ESTRUCTURA DE SALIDA]...
# Restricciones: [LIMITACIONES]...
"""
    
    print(prompt_estudiante)
    
    # Prompt de ejemplo bien estructurado
    ejemplo_prompt = """Eres un HR Business Partner senior especializado en tecnología con 8 años de experiencia reclutando desarrolladores.
    
Tarea: Redacta una descripción de trabajo atractiva y realista para un puesto de Desarrollador Python Junior.
    
Formato requerido:
- Título del puesto
- Resumen ejecutivo (2-3 líneas)
- Responsabilidades principales (4-5 puntos)
- Requisitos técnicos (separar esenciales de deseables)
- Beneficios y cultura de empresa
- Llamada a la acción
    
Restricciones:
- Máximo 400 palabras
- Lenguaje inclusivo y accesible
- Enfócate en crecimiento profesional
- Evita jerga técnica excesiva
- Sé honesto sobre el nivel junior
    
Descripción de trabajo:"""
    
    print("\n=== EJEMPLO DE PROMPT BIEN ESTRUCTURADO ===")
    print(ejemplo_prompt)
    
    # Opcional: probar el prompt ejemplo
    print("\n¿Quieres ver el resultado del prompt ejemplo? (y/n)")
    # En un entorno real, aquí habría input del usuario
    
ejercicio_personalizado()
# Out:
# === EJERCICIO PERSONAL ===
#
# Diseña un prompt zero-shot para esta tarea:
# 'Crear una descripción de trabajo atractiva para un puesto de desarrollador Python junior'
#
# Estructura sugerida:
# 1. Rol/Contexto del modelo
# 2. Tarea específica
# 3. Requisitos del formato
# 4. Restricciones importantes
#
# Tu prompt aquí:
# # COLOCA TU PROMPT AQUÍ
#
# # Ejemplo de estructura:
# # Eres un [ROL]...
# # Tarea: [TAREA ESPECÍFICA]...
# # Formato: [ESTRUCTURA DE SALIDA]...
# # Restricciones: [LIMITACIONES]...
#
#
# === EJEMPLO DE PROMPT BIEN ESTRUCTURADO ===
# Eres un HR Business Partner senior especializado en tecnología con 8 años de experiencia reclutando desarrolladores.
#
# Tarea: Redacta una descripción de trabajo atractiva y realista para un puesto de Desarrollador Python Junior.
#
# Formato requerido:
# - Título del puesto
# - Resumen ejecutivo (2-3 líneas)
# - Responsabilidades principales (4-5 puntos)
# - Requisitos técnicos (separar esenciales de deseables)
# - Beneficios y cultura de empresa
# - Llamada a la acción
#
# Restricciones:
# - Máximo 400 palabras
# - Lenguaje inclusivo y accesible
# - Enfócate en crecimiento profesional
# - Evita jerga técnica excesiva
# - Sé honesto sobre el nivel junior
#
# Descripción de trabajo:
#
# ¿Quieres ver el resultado del prompt ejemplo? (y/n)

# %% [markdown]
# ## Conceptos Clave Aprendidos
#
# 1. **Zero-shot prompting** es efectivo para tareas comunes sin necesidad de ejemplos
# 2. **Estructura clara** del prompt mejora significativamente los resultados
# 3. **Roles específicos** generan respuestas más enfocadas y expertas
# 4. **Instrucciones graduales** ayudan con tareas complejas
# 5. **Formato definido** asegura salidas consistentes y útiles
#
# ## Próximos Pasos
#
# En el siguiente notebook exploraremos **Few-Shot Prompting**, donde aprenderemos a usar ejemplos específicos para guiar el comportamiento del modelo y lograr mayor consistencia en tareas especializadas.
#
# ### Para Practicar:
# 1. Diseña prompts zero-shot para diferentes tipos de tareas
# 2. Experimenta con diferentes roles y contextos
# 3. Compara resultados con y sin estructura específica
# 4. Mide la consistencia en múltiples ejecuciones
